# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# %%
dataset = pd.read_csv(r"SMS_spam_detector_dataset.csv", encoding='latin1')
# dataset = pd.read_csv(r"SMS_spam_detector_dataset.csv")

# %%
dataset
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN
# ...         ...        ...
# 5567        NaN        NaN
# 5568        NaN        NaN
# 5569        NaN        NaN
# 5570        NaN        NaN
# 5571        NaN        NaN
#
# [5572 rows x 5 columns]

# %%
dataset = dataset.iloc[:,:2]
dataset
# Out:
#         v1                                                 v2
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
dataset['v1'].value_counts()
# Out:
# ham     4825
# spam     747
# Name: v1, dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   v1      5572 non-null   object
#  1   v2      5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
dataset['v1'] = dataset['v1'].replace({'ham': 0,'spam' : 1})
# Out:
# C:\Users\kuldeep\AppData\Local\Temp\ipykernel_21064\178888100.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['v1'] = dataset['v1'].replace({'ham': 0,'spam' : 1})

# %%
dataset
# Out:
#       v1                                                 v2
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...
# ...   ..                                                ...
# 5567   1  This is the 2nd time we have tried 2 contact u...
# 5568   0              Will Ì_ b going to esplanade fr home?
# 5569   0  Pity, * was in mood for that. So...any other s...
# 5570   0  The guy did some bitching but I acted like i'd...
# 5571   0                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
y = dataset['v1']
x = dataset['v2']

# %%
# x = x.str.lower()
# x

# %%
# import nltk
# from nltk.tokenize import word_tokenize
# nltk.download('punkt')

# %%
x = x.astype(str)
# x = x.apply(word_tokenize)
# x

# %%
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer

# Convert text to lowercase, remove special characters, tokenize, remove stop words, and perform stemming
x_preprocessed = []
stop_words = set(stopwords.words('english'))
stemmer = PorterStemmer()

for text in x:
    # Convert text to lowercase
    text = text.lower()
    
    # Remove special characters, numbers, and punctuation
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    
    # Tokenize the text
    tokens = word_tokenize(text)
    
    # Remove stop words
    tokens = [word for word in tokens if word not in stop_words]
    
    # Stemming
    tokens = [stemmer.stem(word) for word in tokens]
    
    # Join the tokens back into a single string
    preprocessed_text = ' '.join(tokens)
    
    x_preprocessed.append(preprocessed_text)


tfidf_vectorizer = TfidfVectorizer()
x = tfidf_vectorizer.fit_transform(x_preprocessed)

# %%
x_preprocessed
# Out:
# ['go jurong point crazi avail bugi n great world la e buffet cine got amor wat',
#  'ok lar joke wif u oni',
#  'free entri wkli comp win fa cup final tkt st may text fa receiv entri questionstd txt ratetc appli over',
#  'u dun say earli hor u c alreadi say',
#  'nah dont think goe usf live around though',
#  'freemsg hey darl week word back id like fun still tb ok xxx std chg send rcv',
#  'even brother like speak treat like aid patent',
#  'per request mell mell oru minnaminungint nurungu vettam set callertun caller press copi friend callertun',
#  'winner valu network custom select receivea prize reward claim call claim code kl valid hour',
#  'mobil month u r entitl updat latest colour mobil camera free call mobil updat co free',
#  'im gon na home soon dont want talk stuff anymor tonight k ive cri enough today',
#  'six chanc win cash pound txt csh send cost pday day tsandc appli repli hl info',
#  'urgent week free membership prize jackpot txt word claim tc wwwdbuknet lccltd pobox ldnwarw',
#  'ive search right word thank breather promis wont take help grant fulfil promis wonder bless time',
#  'date sunday',
#  'xxxmobilemovieclub use credit click wap link next txt messag click httpwap xxxmobilemovieclubcomnqjkgighjjgcbl',
#  'oh kim watch',
#  'eh u rememb spell name ye v naughti make v wet',
#  'fine that way u feel that way gota b',
#  'england v macedonia dont miss goalsteam news txt ur nation team eg england trywal scotland txt poboxoxwwq',
#  'serious spell name',
#  'im go tri month ha ha joke',
#  'pay first lar da stock comin',
#  'aft finish lunch go str lor ard smth lor u finish ur lunch alreadi',
#  'ffffffffff alright way meet sooner',
#  'forc eat slice im realli hungri tho suck mark get worri know im sick turn pizza lol',
#  'lol alway convinc',
#  'catch bu fri egg make tea eat mom left dinner feel love',
#  'im back amp pack car ill let know there room',
#  'ahhh work vagu rememb feel like lol',
#  'wait that still clear sure sarcast that x doesnt want live us',
#  'yeah got v apologet n fallen actin like spoilt child got caught till wont go badli cheer',
#  'k tell anyth',
#  'fear faint housework quick cuppa',
#  'thank subscript rington uk mobil charg month pleas confirm repli ye repli charg',
#  'yup ok go home look time msg xuhui go learn nd may lesson',
#  'oop ill let know roommat done',
#  'see letter b car',
#  'anyth lor u decid',
#  'hello how saturday go text see youd decid anyth tomo im tri invit anyth',
#  'pl go ahead watt want sure great weekend abiola',
#  'forget tell want need crave love sweet arabian steed mmmmmm yummi',
#  'rodger burn msg tri call repli sm free nokia mobil free camcord pleas call deliveri tomorrow',
#  'see',
#  'great hope like man well endow ltgt inch',
#  'callsmessagesmiss call',
#  'didnt get hep b immunis nigeria',
#  'fair enough anyth go',
#  'yeah hope tyler cant could mayb ask around bit',
#  'u dont know stubborn didnt even want go hospit kept tell mark im weak sucker hospit weak sucker',
#  'think first time saw class',
#  'gram usual run like ltgt half eighth smarter though get almost whole second gram ltgt',
#  'k fyi x ride earli tomorrow morn he crash place tonight',
#  'wow never realiz embarass accomod thought like sinc best could alway seem happi cave im sorri didnt dont give im sorri offer im sorri room embarass',
#  'sm ac sptv new jersey devil detroit red wing play ice hockey correct incorrect end repli end sptv',
#  'know mallika sherawat yesterday find lturlgt',
#  'congrat year special cinema pass call c suprman v matrix starwar etc free bxipw pm dont miss',
#  'sorri ill call later meet',
#  'tell reach',
#  'yesgauti sehwag odi seri',
#  'gon na pick burger way home cant even move pain kill',
#  'ha ha ha good joke girl situat seeker',
#  'part check iq',
#  'sorri roommat took forev ok come',
#  'ok lar doubl check wif da hair dresser alreadi said wun cut v short said cut look nice',
#  'valu custom pleas advis follow recent review mob award bonu prize call',
#  'today song dedic day song u dedic send ur valuabl frnd first rpli',
#  'urgent ur award complimentari trip eurodisinc trav acoentri claim txt di morefrmmob shracomorsglsuplt ls aj',
#  'hear new divorc barbi come ken stuff',
#  'plane give month end',
#  'wah lucki man save money hee',
#  'finish class',
#  'hi babe im home wan na someth xx',
#  'kkwhere youhow perform',
#  'u call',
#  'wait machan call free',
#  'that cool gentleman treat digniti respect',
#  'like peopl much shi pa',
#  'oper ltgt',
#  'still look job much ta earn',
#  'sorri ill call later',
#  'k call ah',
#  'ok way home hi hi',
#  'place man',
#  'yup next stop',
#  'call later dont network urgnt sm',
#  'real u get yo need ticket one jacket im done alreadi use multi',
#  'ye start send request make pain came back im back bed doubl coin factori got ta cash nitro',
#  'im realli still tonight babe',
#  'ela kanoil download come wen ur free',
#  'yeah dont stand close tho youll catch someth',
#  'sorri pain ok meet anoth night spent late afternoon casualti mean havent done stuffmoro includ time sheet sorri',
#  'smile pleasur smile pain smile troubl pour like rain smile sum hurt u smile becoz someon still love see u smile',
#  'pleas call custom servic repres ampm guarante cash prize',
#  'havent plan buy later check alreadi lido got show e afternoon u finish work alreadi',
#  'free rington wait collect simpli text password mix verifi get usher britney fml',
#  'watch telugu moviewat abt u',
#  'see finish load loan pay',
#  'hi wk ok hol ye bit run forgot hairdress appoint four need get home n shower beforehand caus prob u ham',
#  'pleas dont text anymor noth els say',
#  'okay name ur price long legal wen pick u ave x am xx',
#  'im still look car buy gone drive test yet',
#  'per request mell mell oru minnaminungint nurungu vettam set callertun caller press copi friend callertun',
#  'wow your right didnt mean guess gave boston men chang search locat nyc someth chang cuz signin page still say boston',
#  'umma life vava umma love lot dear',
#  'thank lot wish birthday thank make birthday truli memor',
#  'aight ill hit get cash',
#  'would ip address test consid comput isnt minecraft server',
#  'know grumpi old peopl mom like better lie alway one play joke',
#  'dont worri guess he busi',
#  'plural noun research',
#  'go dinnermsg',
#  'im ok wif co like tri new thing scare u dun like mah co u said loud',
#  'gent tri contact last weekend draw show prize guarante call claim code k valid hr ppm',
#  'wa ur openin sentenc formal anyway im fine juz tt im eatin much n puttin weighthaha anythin special happen',
#  'enter cabin pa said happi bday boss felt special askd lunch lunch invit apart went',
#  'winner u special select receiv holiday flight inc speak live oper claim pmin',
#  'goodo ye must speak friday eggpotato ratio tortilla need',
#  'hmmmi uncl inform he pay school directli pl buy food',
#  'privat account statement show unredeem bonu point claim call identifi code expir',
#  'urgent mobil award bonu caller prize final tri contact u call landlin boxwrc ppm',
#  'new address applespairsal malarki',
#  'today voda number end select receiv award match pleas call quot claim code standard rate app',
#  'go sao mu today done',
#  'predict wat time finish buy',
#  'good stuff',
#  'knowyetund hasnt sent money yet sent text bother send dont involv anyth shouldnt impos anyth first place apologis',
#  'room',
#  'hey girl r u hope u r well del r bak long time c give call sum time lucyxx',
#  'kkhow much cost',
#  'im home',
#  'dear call tmorrowpl accomod',
#  'first answer question',
#  'sunshin quiz wkli q win top soni dvd player u know countri algarv txt ansr sptyron',
#  'want get laid tonight want real dog locat sent direct ur mob join uk largest dog network bt txting gravel nt eca pmsgp',
#  'haf msn yijuehotmailcom',
#  'call meet',
#  'check room befor activ',
#  'youll rcv msg chat svc free hardcor servic text go u get noth u must age verifi yr network tri',
#  'got c lazi type forgot lect saw pouch like v nice',
#  'k text your way',
#  'sir wait mail',
#  'swt thought nver get tire littl thing lovabl person cozsomtim littl thing occupi biggest part heart gud ni',
#  'know pl open back',
#  'ye see ya dot',
#  'what staff name take class us',
#  'freemsg havent repli text im randi sexi femal live local luv hear u netcollex ltd p per msg repli stop end',
#  'ummmawil call check inour life begin qatar pl pray hard',
#  'ki delet contact',
#  'sindu got job birla soft',
#  'wine flow im never',
#  'yup thk cine better co need go plaza mah',
#  'ok ur typic repli',
#  'per request mell mell oru minnaminungint nurungu vettam set callertun caller press copi friend callertun',
#  'everywher dirt floor window even shirt sometim open mouth come flow dream world without half chore time joy lot tv show ill see guess like thing must exist like rain hail mist time done becom one',
#  'aaooooright work',
#  'im leav hous',
#  'hello love get interview today happi good boy think mear miss',
#  'custom servic annonc new year deliveri wait pleas call arrang deliveri',
#  'winner u special select receiv cash holiday flight inc speak live oper claim',
#  'keep safe need miss alreadi envi everyon see real life',
#  'new car hous parentsi new job hand',
#  'im love im excit day spend make happi',
#  'pl stop bootydeli f invit friend repli ye see wwwsmsacubootydeli stop send stop frnd',
#  'bangbab ur order way u receiv servic msg download ur content u goto wap bangb tv ur mobil internetservic menu',
#  'place ur point e cultur modul alreadi',
#  'urgent tri contact last weekend draw show prize guarante call claim code valid hr',
#  'hi frnd best way avoid missunderstd wit belov one',
#  'great escap fanci bridg need lager see tomo',
#  'ye complet formclark also utter wast',
#  'sir need axi bank account bank address',
#  'hmmm thk sure got time hop ard ya go free abt muz call u discuss liao',
#  'time come later',
#  'bloodi hell cant believ forgot surnam mr ill give u clue spanish begin',
#  'well im gon na finish bath goodfin night',
#  'let know youv got money carlo make call',
#  'u still go mall',
#  'turn friend stay whole show wont back til ltgt feel free go ahead smoke ltgt worth',
#  'text doesnt repli let know log',
#  'hi spoke maneesha v wed like know satisfi experi repli toll free ye',
#  'lift hope offer money need especi end month approach hurt studi anyway gr weekend',
#  'lol u trust',
#  'ok gentleman treat digniti respect',
#  'guy close',
#  'go noth greatby',
#  'hello handsom find job lazi work toward get back net mummi where boytoy miss',
#  'haha awesom minut',
#  'pleas call custom servic repres freephon ampm guarante cash prize',
#  'got xma radio time get',
#  'ju reach home go bath first si use net tell u finish k',
#  'uniqu enough find th august wwwareyouuniquecouk',
#  'im sorri ive join leagu peopl dont keep touch mean great deal friend time even great person cost great week',
#  'hi final complet cours',
#  'stop howev suggest stay someon abl give or everi stool',
#  'hope youv settl new school year wishin gr day',
#  'gud mrng dear hav nice day',
#  'u got person stori',
#  'hamster dead hey tmr meet pm orchard mrt',
#  'hi kate even hope see tomorrow bit bloodi babyjontet txt back u xxx',
#  'found enc ltgt',
#  'sent ltgt buck',
#  'hello darlin ive finish colleg txt u finish u love kate xxx',
#  'account refil success inr ltdecimalgt keralacircl prepaid account balanc rs ltdecimalgt transact id kr ltgt',
#  'goodmorn sleep ga',
#  'u call alter ok',
#  'say like dat dun buy ericsson oso oredi lar',
#  'enter cabin pa said happi bday boss felt special askd lunch lunch invit apart went',
#  'aight yo dat straight dogg',
#  'pleas give us connect today ltdecimalgt refund bill',
#  'shoot big load get readi',
#  'what bruv hope great break reward semest',
#  'home alway chat',
#  'kkgoodstudi well',
#  'yup noe leh',
#  'sound great home',
#  'final match head toward draw predict',
#  'tire havent slept well past night',
#  'easi ahsen got select mean good',
#  'take exam march',
#  'yeah think use gt atm regist sure there anyway help let know sure readi',
#  'ok prob take ur time',
#  'os call ubandu run without instal hard diskyou use os copi import file system give repair shop',
#  'sorri ill call later',
#  'u say leh cours noth happen lar say v romant ju bit lor thk e nite sceneri nice leh',
#  'new mobil must go txt nokia collect todayfrom wwwtcbiz optout gbpmtmsg',
#  'would realli appreci call need someon talk',
#  'u meet ur dream partner soon ur career flyng start find free txt horo follow ur star sign e g horo ari',
#  'hey compani elama po mudyadhu',
#  'life strict teacher bcoz teacher teach lesson amp conduct exam life first conduct exam amp teach lesson happi morn',
#  'dear good morn',
#  'get gandhipuram walk cross cut road right side ltgt street road turn first right',
#  'dear go rubber place',
#  'sorri batteri die yeah im',
#  'yesher tv alway avail work place',
#  'text meet someon sexi today u find date even flirt u join p repli name age eg sam msg recdthirtyeight penc',
#  'print oh ltgt come upstair',
#  'ill littl closer like bu stop street',
#  'youwhen wil reach',
#  'new theori argument win situat lose person dont argu ur friend kick amp say im alway correct',
#  'u secret admir look make contact ufind rreveal think ur specialcal',
#  'tomarrow final hear laptop case cant',
#  'pleassssssseeeee tel v avent done sportsx',
#  'okay shine meant sign sound better',
#  'although told u dat im baig face watch realli like e watch u gave co fr u thanx everyth dat uve done today im touch',
#  'u dont rememb old commerci',
#  'late said websit didnt dont slipper',
#  'ask call ok',
#  'kalli wont bat nd inning',
#  'didnt work oh ok goodnight ill fix readi time wake dearli miss good night sleep',
#  'congratul ur award cd voucher gift guarante free entri wkli draw txt music tnc wwwldewcomwinppmxag',
#  'ranjith cal drpd deeraj deepak min hold',
#  'wen ur lovabl bcum angri wid u dnt take serious coz angri childish n true way show deep affect care n luv kettoda manda nice day da',
#  'doinghow',
#  'up day also ship compani take wk way usp take week get lag may bribe nipost get stuff',
#  'im back lem know your readi',
#  'dont necessarili expect done get back though im headin',
#  'mmm yummi babe nice jolt suzi',
#  'lover need',
#  'tri contact repli offer video handset anytim network min unlimit text camcord repli call',
#  'im park next mini come today think',
#  'yup',
#  'anyway im go shop co si done yet dun disturb u liao',
#  'luton ring ur around h',
#  'hey realli horni want chat see nake text hot text charg pm unsubscrib text stop',
#  'dint come us',
#  'wana plan trip sometm',
#  'sure yet still tri get hold',
#  'ur rington servic chang free credit go clubmobilescom choos content stop txt club stop pwk club po box mk wt',
#  'evo download flash jealou',
#  'rington club get uk singl chart mobil week choos top qualiti rington messag free charg',
#  'come mu sort narcot situat',
#  'night end anoth day morn come special way may smile like sunni ray leav worri blue blue bay',
#  'hmv bonu special pound genuin hmv voucher answer easi question play send hmv infowwwpercentrealcom',
#  'usf guess might well take car',
#  'object bf come',
#  'thanx',
#  'tell rob mack gf theater',
#  'awesom ill see bit',
#  'sent type food like',
#  'done hand celebr full swing yet',
#  'got call tool',
#  'wen u miss someon',
#  'ok ask money far',
#  'oki',
#  'yeah think usual guy still pass last night get ahold anybodi let know ill throw',
#  'k might come tonight class let earli',
#  'ok',
#  'hi babi im cruisin girl friend r u give call hour home that alright fone fone love jenni xxx',
#  'life mean lot love life love peopl life world call friend call world ge',
#  'dearshal mail tonitebusi streetshal updat toniteth look okvarunnathu edukkukaye raksha ollubut good one real sens',
#  'hey told name gautham ah',
#  'haf u found feel stupid da v cam work',
#  'oop got bit',
#  'much buzi',
#  'accident delet messag resend pleas',
#  'tmobil custom may claim free camera phone upgrad pay go sim card loyalti call offer end thfebtc appli',
#  'unless situat go gurl would appropri',
#  'hurt teas make cri end life die plz keep one rose grave say stupid miss u nice day bslvyl',
#  'cant pick phone right pl send messag',
#  'need coffe run tomoc believ time week alreadi',
#  'awesom rememb last time got somebodi high first time diesel v',
#  'shit realli shock scari cant imagin second def night u think somewher could crash night save taxi',
#  'oh way food fridg want go meal tonight',
#  'womdarful actor',
#  'sm ac blind date u rodd aberdeen unit kingdom check httpimg sm acwicmbcktzr blind date send hide',
#  'yup remb think book',
#  'jo ask u wana meet',
#  'lol ye friendship hang thread caus u wont buy stuff',
#  'themob check newest select content game tone gossip babe sport keep mobil fit funki text wap',
#  'garag key arent bookshelf',
#  'today accept dayu accept brother sister lover dear best clo lvblefrnd jstfrnd cutefrnd lifpartnr belovd swtheart bstfrnd rpli mean enemi',
#  'think ur smart win week weekli quiz text play nowtc winnersclub po box uz gbpweek',
#  'say hell give call friend got money he definit buy end week',
#  'hi way u day normal waythi real ur uniquei hope know u rest mylif hope u find wot lost',
#  'made day great day',
#  'kkadvanc happi pongal',
#  'hmmm guess go kb n power yoga haha dunno tahan power yoga anot thk got lo oso forgot liao',
#  'realli dude friend im afraid',
#  'decemb mobil mth entitl updat latest colour camera mobil free call mobil updat co free',
#  'coffe cake guess',
#  'merri christma babe love ya kiss',
#  'hey dont go watch x men lunch haha',
#  'cud u tell ppl im gona b bit l co buse hav gon past co full im still waitin pete x',
#  'would great well guild could meet bristol road somewher get touch weekend plan take flight good week',
#  'problem',
#  'callsmessagesmiss call',
#  'hi dahow today class',
#  'id say that good sign well know track record read women',
#  'cool text your park',
#  'im read text sent meant joke read light',
#  'kkapo kgood movi',
#  'mayb could get book tomo return immedi someth',
#  'call germani penc per minut call fix line via access number prepay direct access',
#  'chanc might evapor soon violat privaci steal phone number employ paperwork cool pleas contact report supervisor',
#  'valentin day special win quiz take partner trip lifetim send go pmsg rcvd custcar',
#  'tadaaaaa home babe still',
#  'cool come havent wine dine',
#  'sleepingand surf',
#  'sorri ill call later',
#  'u call right call hand phone',
#  'ok that great thanx lot',
#  'take post come must text happi read one wiv hello carolin end favourit bless',
#  'u hide stranger',
#  'interest like',
#  'sister clear two round birla soft yesterday',
#  'gudnitetcpractic go',
#  'di yiju ju saw ur mail case huim havent sent u num di num',
#  'one small prestig problem',
#  'fanci shag dointerest sextextukcom txt xxuk suzi txt cost per msg tnc websit x',
#  'check realli miss see jeremiah great month',
#  'nah cant help ive never iphon',
#  'your car hour half im go apeshit',
#  'today sorri day ever angri ever misbehav hurt plz plz slap urself bcoz ur fault im basic good',
#  'yo guy ever figur much need alcohol jay tri figur much safe spend weed',
#  'ltgt ish minut minut ago wtf',
#  'thank callingforgot say happi onam sirjii fine rememb met insur personmeet qatar insha allahrakhesh ex tata aig join tisscotays',
#  'congratul ur award cd voucher gift guarante free entri wkli draw txt music tnc wwwldewcomwinppmxag',
#  'ur cashbal current pound maxim ur cashin send cash pmsg cc hgsuiteland rowwjhl',
#  'im actor work work even sleep late sinc im unemploy moment alway sleep late your unemploy everi day saturday',
#  'hello got st andrewsboy long way cold keep post',
#  'ha ha cool cool chikku chikkudb',
#  'oh ok prob',
#  'check audrey statu right',
#  'busi tri finish new year look forward final meet',
#  'good afternoon sunshin dawn day refresh happi aliv breath air smile think love alway',
#  'well know z take care worri',
#  'updatenow xma offer latest motorola sonyericsson nokia free bluetooth doubl min txt orang call mobileupd calloptoutfq',
#  'discount code rp stop messag repli stop wwwregalportfoliocouk custom servic',
#  'wat uniform get',
#  'cool text your readi',
#  'hello boytoy geeee miss alreadi woke wish bed cuddl love',
#  'spoil bed well',
#  'im go bath msg next ltgt min',
#  'cant keep talk peopl sure pay agre price pl tell want realli buy much will pay',
#  'thank rington order refer charg gbp per week unsubscrib anytim call custom servic',
#  'say happen',
#  'could seen mei didt recognis face',
#  'well there lot thing happen lindsay new year sigh bar ptbo blue heron someth go',
#  'keep payasam rinu bring',
#  'taught ranjith sir call sm like becau he verifi project prabu told today pa dont mistak',
#  'guess that worri must know there way bodi repair im quit sure shouldnt worri well take slow first test guid ovul relax noth youv said reason worri ill keep followin',
#  'yeah sure give coupl minut track wallet',
#  'hey leav big deal take care',
#  'hey late ah meet',
#  'doubl min txt month free bluetooth orang avail soni nokia motorola phone call mobileupd calloptoutndx',
#  'took mr owl lick',
#  'custom place call',
#  'mm time dont like fun',
#  'mth half price orang line rental latest camera phone free phone mth call mobilesdirect free updat orstoptxt',
#  'yup lunch buffet u eat alreadi',
#  'huh late fr dinner',
#  'hey sat go intro pilat kickbox',
#  'morn ok',
#  'ye think offic lap room think that last day didnt shut',
#  'pick bout ish time go',
#  'perform award calcul everi two monthnot current one month period',
#  'actual sleep still might u call back text gr rock si send u text wen wake',
#  'alway put busi put pictur ass facebook one open peopl ive ever met would think pictur room would hurt make feel violat',
#  'good even sir al salam wahleykkumshar happi newsbi grace god got offer tayseertissco joinedhop fineinshah allahmeet sometimerakheshvisitor india',
#  'hmmmkbut want chang field quickli dai wan na get system administr network administr',
#  'free rington text first poli text get true tone help st free tone xpw end txt stop',
#  'dear chechi talk',
#  'hair cream ship',
#  'none that happen til get though',
#  'yep great loxahatche xma tree burn ltgt start hour',
#  'haha get use drive usf man know lot stoner',
#  'well slightli disastr class pm fav darl hope day ok coffe wld good cant stay late tomorrow time place alway',
#  'hello good week fanci drink someth later',
#  'headin toward busetop',
#  'messagesom text miss sendernam miss number miss sentdat miss miss u lot that everyth miss sent via fullonsmscom',
#  'come room point iron plan weekend',
#  'co want thing',
#  'oki ill go yan jiu skip ard oso go cine den go mrt one blah blah blah',
#  'bring home wendi',
#  'date servic call boxskch',
#  'whatsup dont u want sleep',
#  'alright new goal',
#  'free entri weekli competit text word win tc wwwtxttowincouk',
#  'alright ill head minut text meet',
#  'send logo ur lover name join heart txt love name name mobno eg love adam eve yahoo poboxwwq txtno ad p',
#  'yesfrom last week im take live call',
#  'someon contact date servic enter phone fanci find call landlin poboxntfp',
#  'siva hostel aha',
#  'urgent mobil number award prize guarante call land line claim valid hr',
#  'send ur friend receiv someth ur voic speak express childish naughti sentiment rowdi ful attitud romant shi attract funni ltgt irrit ltgt lovabl repli',
#  'ok shell ok guess',
#  'aathiwher dear',
#  'pain urin thing els',
#  'esplanad mind give lift co got car today',
#  'wnt buy bmw car urgentlyit vri urgentbut hv shortag ltgt lacsther sourc arng di amt ltgt lacsthat prob',
#  'home watch tv lor',
#  'usual take fifteen fuck minut respond ye question',
#  'congrat nokia video camera phone call call cost ppm ave call min vari mobil close post bcm ldn wcnxx',
#  'book ticket pongal',
#  'avail im like right around hillsborough amp ltgt th',
#  'messag sent askin ltgt dollar shoul pay ltgt ltgt',
#  'ask g iouri ive told stori like ten time alreadi',
#  'long applebe fuck take',
#  'hi hope u get txtjourney hasnt gdnow min late think',
#  'like love arrang',
#  'yesh realli greatbhaji told kalli best cricket sachin worldveri tough get',
#  'suppos wake gt',
#  'oic saw tot din c found group liao',
#  'sorri ill call later',
#  'hey hey wereth monkeespeopl say monkeyaround howdi gorgeou',
#  'sorri batteri die come im get gram where place',
#  'well done blimey exercis yeah kinda rememb wot hmm',
#  'wont get concentr dear know mind everyth',
#  'lol made plan new year',
#  'min later k',
#  'hank lotsli',
#  'thank hope good day today',
#  'kkwhat detail want transferacc enough',
#  'ok tell stay yeah tough optimist thing improv month',
#  'loan purpos homeown tenant welcom previous refus still help call free text back help',
#  'si si think ill go make oreo truffl',
#  'look ami ure beauti intellig woman like u lot know u dont like like dont worri',
#  'hope that result consist intellig kind start ask practicum link keep ear open best ttyl',
#  'call cost guess isnt bad miss ya need ya want ya love ya',
#  'go thru differ feelingwav decis cope individualtim heal everyth believ',
#  'u go phone gon na die stay',
#  'great never better day give even reason thank god',
#  'upgrdcentr orang custom may claim free camera phone upgrad loyalti call offer end th juli tc appli optout avail',
#  'sorri ill call later ok bye',
#  'ok way railway',
#  'great princess love give receiv oral doggi style fave posit enjoy make love ltgt time per night',
#  'dont put stuff road keep get slipperi',
#  'go ride bike',
#  'yup need ill ju wait e rain stop',
#  'mani compani tell languag',
#  'okmail dear dave final notic collect tenerif holiday cash award call landlin tc sae box cwwx ppm',
#  'long sinc scream princess',
#  'noth meant money enter account bank remov flat rate someon transfer ltgt account ltgt dollar got remov bank differ charg also differb sure trust ja person send account detail co',
#  'want get laid tonight want real dog locat sent direct ur mob join uk largest dog network txting moan nyt eca pmsgp',
#  'nice line said broken heart plz dont cum time infront wise trust u good',
#  'ok im gon na head usf like fifteen minut',
#  'love aathilov u lot',
#  'tension ahwhat machiani problem',
#  'k pick anoth th your done',
#  'whenr guy get back g said think stay mcr',
#  'almost see u sec',
#  'yo carlo friend alreadi ask work weekend',
#  'watch tv lor',
#  'thank babi cant wait tast real thing',
#  'chang fb jaykwon thuglyf falconerf',
#  'win realli side long time',
#  'free messag activ free text messag repli messag word free term condit visit wwwcom',
#  'dear reach railway happen',
#  'depend qualiti want type sent boy fade glori want ralph mayb',
#  'think ive fix send test messag',
#  'sorri man account dri would want could trade back half could buy shit credit card',
#  'congrat year special cinema pass call c suprman v matrix starwar etc free bxipw pm dont miss',
#  'sorryin meet ill call later',
#  'class ltgt reunion',
#  'free nowcan call',
#  'got meh',
#  'nope think go monday sorri repli late',
#  'told accentur confirm true',
#  'kate jackson rec center ish right',
#  'dear reach room',
#  'fight world easi u either win lose bt fightng close u dificult u lose u lose u win u still lose',
#  'come',
#  'check nuerologist',
#  'lolnic went fish water',
#  'congratul week competit draw u prize claim call b tcsstop sm ppm',
#  'wait e car dat bore wat co wait outsid got noth home stuff watch tv wat',
#  'mayb westshor hyde park villag place near hous',
#  'know how anthoni bring money ive school fee pay rent stuff like that need help friend need',
#  'what signific',
#  'opinion jada kusruthi lovabl silent spl charact matur stylish simpl pl repli',
#  'latest gs still scroung ammo want give new ak tri',
#  'prabhaim sorydarealyfrm heart im sori',
#  'lol ok forgiven',
#  'nojst chang tat',
#  'guarante latest nokia phone gb ipod mp player prize txt word collect ibhltd ldnwh pmtmsgrcvd',
#  'sno competit',
#  'boltblu tone p repli poli mono eg poli cha cha slide yeah slow jamz toxic come stop tone txt',
#  'credit top httpwwwbubbletextcom renew pin tgxxrz',
#  'way transport less problemat sat night way u want ask n join bday feel free need know definit no book fri',
#  'usual person unconsci that children adult may behav abnorm ill call',
#  'that ebay might less elsewher',
#  'shall come get pickl',
#  'gon na go get taco',
#  'that rude campu',
#  'urgent mobil award bonu caller prize nd attempt contact call boxqu',
#  'hi wont b ard christma enjoy n merri xma',
#  'today offer claim ur worth discount voucher text ye savamob member offer mobil cs sub unsub repli x',
#  'ye pretti ladi like singl',
#  'reciev tone within next hr term condit pleas see channel u teletext pg',
#  'jay say your doublefaggot',
#  'privat account statement show unredeem sim point call identifi code expir',
#  'todaysundaysunday holidayso work',
#  'gudnitetcpractic go',
#  'ill late',
#  'ive call hope lr malaria know miss guy miss bani big pl give love especi great day',
#  'good afternoon love goe day hope mayb got lead job think boytoy send passion kiss across sea',
#  'probabl gon na see later tonight lt',
#  'mayb fat finger press button doesnt know',
#  'ummmmmaah mani mani happi return day dear sweet heart happi birthday dear',
#  'tirupur da start offic call',
#  'wwwapplausestorecom monthlysubscriptionpmsg maxmonth tcsc web age stop txt stop',
#  'famou quot develop abil listen anyth uncondit without lose temper self confid mean marri',
#  'go colleg pa els ill come self pa',
#  'oclock mine bash flat plan',
#  'girl stay bed girl doesnt need recoveri time id rather pass fun coop bed',
#  'special',
#  'know need get hotel got invit apologis cali sweet come english bloke weddin',
#  'sorri took long omw',
#  'wait ltgt min',
#  'ok give minut think see btw your alibi cut hair whole time',
#  'imagin final get sink bath put pace mayb even eat left also imagin feel cage cock surround bath water remind alway own enjoy cuck',
#  'hurri ive weeddefici like three day',
#  'sure get acknowledg astoundingli tactless gener faggi demand blood oath fo',
#  'ok everi night take warm bath drink cup milk youll see work magic still need loos weight know',
#  'ill look fri pan case cheap book perhap that silli fri pan isnt like book',
#  'well uv caus mutat sunscreen like essenti theseday',
#  'lunchyou onlinewhi',
#  'know friend alreadi told',
#  'hi princess thank pic pretti',
#  'aiyo u alway c ex one dunno abt mei repli first time u repli fast lucki workin huh got bao ur sugardad ahge',
#  'hi msg meim offic',
#  'thanx e browni v nice',
#  'geeeee love much bare stand',
#  'gent tri contact last weekend draw show prize guarante call claim code k valid hr ppm',
#  'fuck babe miss alreadi know cant let send money toward net need want crave',
#  'ill call u mrw ninish address icki american freek wont stop callin bad jen k eh',
#  'oooh bed ridden ey think',
#  'anyway go gym whatev love smile hope ok good day babe miss much alreadi',
#  'love daddi make scream pleasur go slap ass dick',
#  'wot u wan na missi',
#  'yar lor wait mum finish sch lunch lor whole morn stay home clean room room quit clean hee',
#  'know lab goggl went',
#  'open door',
#  'wait call',
#  'nope wait sch daddi',
#  'cash prize claim call',
#  'im tire argu week week want ill',
#  'wait sch finish ard',
#  'mobil number claim call us back ring claim hot line',
#  'arngd marriag u r walkin unfortuntli snake bite u bt love marriag danc frnt snake amp sayin bite bite',
#  'huh earli dinner outsid izzit',
#  'ok anyway need chang said',
#  'tri contact repli offer min textand new video phone call repli free deliveri tomorrow',
#  'exwif abl kid want kid one day',
#  'how scotland hope show jjc tendenc take care live dream',
#  'tell u headach want use hour sick time',
#  'dun thk ill quit yet hmmm go jazz yogasana oso go meet em lesson den',
#  'pete pleas ring meiv hardli gotani credit',
#  'ya srsli better yi tho',
#  'im meet call later',
#  'ur chanc win wkli shop spree txt shop tsc wwwtxtshopcom custcar xpwk',
#  'special select receiv pound award call line close cost ppm tc appli ag promo',
#  'privat account statement show unredeem point call identifi code expir',
#  'still grand prix',
#  'met stranger choos friend long world stand friendship never end let friend forev gud nitz',
#  'great',
#  'gud mrng dear nice day',
#  'import custom servic announc call freephon',
#  'exhaust train morn much wine pie sleep well',
#  'im go buy mum present ar',
#  'mind blastin tsunami occur rajnik stop swim indian oceand',
#  'u send home first ok lor im readi yet',
#  'speak cash yet',
#  'happi come noon',
#  'meet lunch la',
#  'take care n get well soon',
#  'xclusiveclubsaisai morow soire special zouk nichol parisfre rose ladi info',
#  'meant say cant wait see u get bore bridgwat banter',
#  'neva mind ok',
#  'fine imma get drink somethin want come find',
#  'day kick euro u kept date latest news result daili remov send get txt stop',
#  'valentin game send di msg ur friend answer r someon realli love u que colour suit bestrpli',
#  'mani depend',
#  'thanx today cer nice catch ave find time often oh well take care c u soonc',
#  'call said himthen choos futur',
#  'happi valentin day know earli hundr handsom beauti wish thought finish aunti uncl st',
#  'like v shock leh co tell shuhui like tell leona also like dat almost know liao got ask abt ur reaction lor',
#  'famili happi',
#  'come n pick come immedi aft ur lesson',
#  'let snow let snow kind weather bring ppl togeth friendship grow',
#  'dear got ltgt dollar hi hi',
#  'good word word may leav u dismay mani time',
#  'make sure alex know birthday fifteen minut far your concern',
#  'sorri got thing may pub later',
#  'nah straight bring bud drink someth that actual littl use straight cash',
#  'haha good hear im offici paid market th',
#  'mani lick take get center tootsi pop',
#  'yup thk r e teacher said make face look longer darren ask cut short',
#  'new textbuddi chat horni guy ur area p free receiv search postcod gaytextbuddycom txt one name',
#  'today vodafon number end select receiv award number match call receiv award',
#  'pleas dont say like hi hi hi',
#  'thank u',
#  'oh forward messag thought send',
#  'got seventeen pound seven hundr ml hope ok',
#  'dear voucher holder claim week offer pc go httpwwwetlpcoukexpressoff tsc appli stop text txt stop',
#  'n funni',
#  'sweetheart hope kind day one load reason smile biola',
#  'login dat time dad fetch home',
#  'shower babi',
#  'askd u question hour answer',
#  'well imma definit need restock thanksgiv ill let know im',
#  'said kiss kiss cant sound effect gorgeou man isnt kind person need smile brighten day',
#  'probabl gon na swing wee bit',
#  'ya nice readi thursday',
#  'allo brave buse taken train triumph mean bham jolli good rest week',
#  'watch cartoon listen music amp eve go templ amp church u',
#  'mind ask happen dont say uncomfort',
#  'privat account statement show unredeem point call identifi code expir',
#  'prob send email',
#  'cash prize claim call tc rstm sw ss ppm',
#  'that cool sometim slow gentl sonetim rough hard',
#  'im gon na say sorri would normal start panic time sorri see tuesday',
#  'wait know wesley town bet hella drug',
#  'fine miss much',
#  'u got person stori',
#  'tell drug dealer get impati',
#  'sun cant come earth send luv ray cloud cant come river send luv rain cant come meet u send care msg u gud evng',
#  'place man',
#  'doesnt make sens take unless free need know wikipediacom',
#  'premium phone servic call',
#  'sea lay rock rock envelop envelop paper paper word',
#  'mum repent',
#  'sorri go home first daddi come fetch later',
#  'leav de start prepar next',
#  'ye babi studi posit kama sutra',
#  'en chikku nang bakra msg kalstiyathen teacoffe',
#  'carlosl minut still need buy',
#  'pay ltdecimalgt lakh',
#  'good even ttyl',
#  'u receiv msg',
#  'ho ho big belli laugh see ya tomo',
#  'sm ac sun post helloy seem cool',
#  'get ur st rington free repli msg tone gr top tone phone everi week per wk opt send stop',
#  'ditto wont worri say anyth anymor like said last night whatev want ill peac',
#  'ive got ltgt way could pick',
#  'dont knw pa drink milk',
#  'mayb say hi find got card great escap wetherspoon',
#  'piggi r u awak bet ure still sleep im go lunch',
#  'caus im freaki lol',
#  'miss call caus yell scrappi miss u cant wait u come home im lone today',
#  'hex place talk explain',
#  'log wat sdrybi',
#  'xy go e lunch',
#  'hi im sue year old work lapdanc love sex text live im bedroom text sue textoper g da ppmsg',
#  'want ask wait finish lect co lect finish hour anyway',
#  'finish work yet',
#  'everi king cri babi everi great build map imprtant u r today u wil reach tomorw gud ni',
#  'dearm cherthalain case u r come cochin pl call bfore u starti shall also reach accordinglyor tell day u r comingtmorow engag an holiday',
#  'thank love torch bold',
#  'forward pleas call immedi urgent messag wait',
#  'farm open',
#  'sorri troubl u buy dad big small sat n sun thanx',
#  'sister law hope great month say hey abiola',
#  'purchas stuff today mail po box number',
#  'ah poop look like ill prob send laptop get fix cuz gpu problem',
#  'good good job like entrepreneur',
#  'aight close still around alex place',
#  'meet corpor st outsid gap see mind work',
#  'mum ask buy food home',
#  'ku also dont msg repli msg',
#  'much r will pay',
#  'sorri ill call later',
#  'import prevent dehydr give enough fluid',
#  'that bit weird even suppos happen good idea sure pub',
#  'true deari sat pray even felt soso smsd time',
#  'dont think get away trek long famili town sorri',
#  'wan na gym harri',
#  'quit late lar ard anyway wun b drivin',
#  'review keep fantast nokia ngage game deck club nokia go wwwcnupdatescomnewslett unsubscrib alert repli word',
#  'mth half price orang line rental latest camera phone free phone mth call mobilesdirect free updat orstoptxt tc',
#  'height confid aeronaut professor wer calld amp wer askd sit aeroplan aftr sat wer told dat plane ws made student dey hurri plane bt didnt move saidif made student',
#  'seem like weird time night g want come smoke day shitstorm attribut alway come make everyon smoke',
#  'ampm cost p',
#  'save stress person dorm account send account detail money sent',
#  'also know lunch menu da know',
#  'stuff sell ill tell',
#  'urgent nd attempt contact uu call b tcsbcmwcnxx callcost ppm mobilesvari max',
#  'book lesson msg call work sth im go get spec membership px',
#  'guarante cash prize claim yr prize call custom servic repres ampm',
#  'macha dont feel upseti assum mindsetbeliev one even wonder plan uslet life begin againcal anytim',
#  'oh send address',
#  'sfine anytim best',
#  'wondar full flim',
#  'ya even cooki jelli',
#  'world run stillmayb feel sameso itor admiti madthen correctionor let call lifeand keep run worldmay u r also runninglet run',
#  'got look scrumptiou daddi want eat night long',
#  'co lar im ba dao ok pm lor u never ask go ah said u would ask fri said u ask today',
#  'alright omw got ta chang order halfth',
#  'exactli anyway far jide studi visit',
#  'dunno u ask',
#  'email alertfrom jeri stewarts kbsubject lowcost prescripiton drvgsto listen email call',
#  'didnt spring come earli yay',
#  'lol wont feel bad use money take steak dinner',
#  'even u dont get troubl convincingjust tel twice tel neglect msg dont c read itjust dont repli',
#  'leav qatar tonit search opportunityal went fastpl add ur prayer dearrakhesh',
#  'one talk',
#  'thank look realli appreci',
#  'hi custom loyalti offerth new nokia mobil txtauction txt word start get tctxt tc pmtmsg',
#  'wish',
#  'haha mayb ure rite u know well da feel like someon gd lor u faster go find one gal group attach liao',
#  'ye glad made',
#  'well littl time thing good time ahead',
#  'got room soon hadnt put clock back til shout everyon get realis wahay anoth hour bed',
#  'ok may free gym',
#  'men like shorter ladi gaze eye',
#  'dunno ju say go lido time',
#  'promis take good care princess run pleas send pic get chanc ttyl',
#  'u subscrib best mobil content servic uk per day send stop helplin',
#  'reason weve spoken year anyway great week best exam',
#  'monday next week give full gist',
#  'realiz year well thousand old ladi run around tattoo',
#  'import custom servic announc premier',
#  'dont gim lip caveboy',
#  'get librari',
#  'reali sorryi dont recognis number confus r u pleas',
#  'didnt holla',
#  'cant think anyon spare room top head',
#  'faith make thing possiblehop make thing worklov make thing beautifulmay three christmasmerri christma',
#  'u made appoint',
#  'call youcarlo isar phone vibrat act might hear text',
#  'romant pari night flight book next year call tsc appli',
#  'grandma oh dear u still ill felt shit morn think hungov anoth night leav sat',
#  'urgent ur guarante award still unclaim call closingd claimcod mm pmmorefrommobilebremovedmobypoboxlsyf',
#  'noth ju tot u would ask co u ba gua went mt faber yest yest ju went alreadi mah today go ju call lor',
#  'wish famili merri x ma happi new year advanc',
#  'ur award citi break could win summer shop spree everi wk txt store skilgm tscswinawkag perwksub',
#  'im nt goin got somethin unless meetin dinner lor haha wonder go ti time',
#  'sorri ill call later',
#  'cant pick phone right pl send messag',
#  'lol know theyr dramat school alreadi close tomorrow appar cant drive inch snow suppos get',
#  'get anywher damn job hunt',
#  'lol u drunkard hair moment yeah still tonight wat plan',
#  'idc get weasel way shit twice row',
#  'wil ltgt minut got space',
#  'sleepingand surf',
#  'thank pick trash',
#  'dont go tell friend your sure want live smoke much spend hour beg come smoke',
#  'hi kate love see tonight ill phone tomorrow got sing guy gave card xxx',
#  'happi new year dear brother realli miss got number decid send text wish happi abiola',
#  'mean get door',
#  'opinion jada kusruthi lovabl silent spl charact matur stylish simpl pl repli',
#  'hmmm thought said hour slave late punish',
#  'beerag',
#  'import custom servic announc premier call freephon',
#  'dont think turn like randomlli within min open',
#  'suppos couldnt make she still town though',
#  'time fix spell sometim get complet diff word go figur',
#  'ever thought live good life perfect partner txt back name age join mobil commun psm',
#  'free top polyphon tone call nation rate get toppoli tune sent everi week text subpoli per pole unsub',
#  'gud mrng dear hav nice day',
#  'hope enjoy game yesterday sorri ive touch pl know fondli bein thot great week abiola',
#  'e best ur drive tmr',
#  'ywhere u dogbreath sound like jan c that al',
#  'omg want scream weigh lost weight woohoo',
#  'gener isnt one uncount noun u dictionari piec research',
#  'realli get hang around',
#  'orang custom may claim free camera phone upgrad loyalti call offer end thmarch tc appli optout availa',
#  'petey boy wherear friendsar thekingshead come canlov nic',
#  'ok msg u b leav hous',
#  'gim ltgt minut ago',
#  'last chanc claim ur worth discount voucher today text shop savamob offer mobil cs savamob pobox muz sub',
#  'appt lttimegt fault u dont listen told u twice',
#  'free st week nokia tone ur mobil everi week txt nokia get txting tell ur mate wwwgetzedcouk pobox wwq normpton',
#  'guarante award even cashto claim ur award call free stop getstop php rg jx',
#  'k ill',
#  'dled imp',
#  'sure make sure know aint smokin yet',
#  'boooo alway work quit',
#  'take half day leav bec well',
#  'ugh dont wan na get bed warm',
#  'ssnervou ltgt',
#  'there ring come guy costum gift futur yowif hint hint',
#  'congratul ur award either cd gift voucher free entri weekli draw txt music tnc wwwldewcomwinppmxag',
#  'borrow ur bag ok',
#  'u outbid simonwatson shinco dvd plyr bid visit sm acsmsreward end bid notif repli end',
#  'where boytoy miss happen',
#  'lot use one babe model doesnt help youi bring hell match',
#  'also bring galileo dobbi',
#  'respond',
#  'boo babe u enjoyin yourjob u seem b gettin well hunnyhop ure oktak care illspeak u soonlot lovem xxxx',
#  'good afternoon starshin how boytoy crave yet ach fuck sip cappuccino miss babe teas kiss',
#  'road cant txt',
#  'smsservic yourinclus text credit pl goto wwwcomuknet login qxj unsubscrib stop extra charg help comuk cm ae',
#  'p alfi moon children need song ur mob tell ur ms txt tone chariti nokia poli chariti poli zed profit chariti',
#  'good even ttyl',
#  'hmm bit piec lol sigh',
#  'hahahaus brain dear',
#  'hey got mail',
#  'sorri light turn green meant anoth friend want ltgt worth may around',
#  'thank yesterday sir wonder hope enjoy burial mojibiola',
#  'u secret admir reveal think u r special call opt repli reveal stop per msg recd cust care',
#  'hi mate rv u hav nice hol messag say hello coz havent sent u age start drive stay roadsrvx',
#  'dear voucher holder claim week offer pc pleas go httpwwwetlpcoukexpressoff tsc appli stop text txt stop',
#  'thank much skype wit kz sura didnt get pleasur compani hope good weve given ultimatum oh countin aburo enjoy messag sent day ago',
#  'sure result offer',
#  'good morn dear great amp success day',
#  'want anytim network min text new video phone five pound per week call repli deliveri tomorrow',
#  'sir late pay rent past month pay ltgt charg felt would inconsider nag someth give great cost that didnt speak howev recess wont abl pay charg month henc askin well ahead month end pleas help thank',
#  'tri contact offer new video phone anytim network min half price rental camcord call repli deliveri wed',
#  'last chanc claim ur worth discount voucherstext ye nowsavamobmemb offer mobil cs sub remov txt x stop',
#  'luv u soo much u dont understand special u r ring u morrow luv u xxx',
#  'pl send comprehens mail im pay much',
#  'prashanthettan mother pass away last night pray famili',
#  'urgent call landlin complimentari ibiza holiday cash await collect sae tc po box sk wp ppm',
#  'kkwhen go',
#  'meanwhil shit suit xavier decid give us ltgt second warn samantha come play jay guitar impress shit also dont think doug realiz dont live anymor',
#  'stomach thru much trauma swear cant eat better lose weight',
#  'officewhat mattermsg nowi call break',
#  'yeah there bare enough room two us x mani fuck shoe sorri man see later',
#  'today offer claim ur worth discount voucher text ye savamob member offer mobil cs sub unsub repli x',
#  'u reach orchard alreadi u wan go buy ticket first',
#  'real babi want bring inner tigress',
#  'da run activ full version da',
#  'ah poor babyhop urfeel bettersn luv probthat overdos work hey go care spk u sn lot lovejen xxx',
#  'stop stori ive told ive return he say order',
#  'talk sexi make new friend fall love world discreet text date servic text vip see could meet',
#  'go take babe',
#  'hai ana tomarrow come morn ltdecimalgt ill sathi go rto offic repli came home',
#  'spoon okay',
#  'say somebodi name tampa',
#  'work go min',
#  'brother geniu',
#  'sorri guess whenev get hold connect mayb hour two ill text',
#  'u find time bu coz need sort stuff',
#  'dude ive see lotta corvett late',
#  'congratul ur award either yr suppli cd virgin record mysteri gift guarante call tsc wwwsmsconet pm approx min',
#  'consid wall bunker shit import never play peac guess place high enough dont matter',
#  'privat account statement xxxxxx show unredeem point call identifi code expir',
#  'hello need posh bird chap user trial prod champney put need address dob asap ta r',
#  'u want xma free text messag new video phone half price line rental call free find',
#  'well offici philosoph hole u wan na call home readi save',
#  'go goodno problembut still need littl experi understand american custom voic',
#  'ill text drop x',
#  'ugh long day im exhaust want cuddl take nap',
#  'talk atleast day otherwis miss best friend world shakespear shesil ltgt',
#  'shop till u drop either k k cash travel voucher call ntt po box crbt fixedlin cost ppm mobil vari',
#  'castor need see someth',
#  'sunshin quiz wkli q win top soni dvd player u know countri liverpool play mid week txt ansr sptyron',
#  'u secret admir look make contact ufind rreveal think ur specialcal',
#  'u secret admir look make contact ufind rreveal think ur specialcal stopsm',
#  'remind download content alreadi paid goto httpdoit mymobi tv collect content',
#  'see knew give break time woul lead alway want miss curfew gon na gibe til one midnight movi gon na get til need come home need getsleep anyth need b studdi ear train',
#  'love give massag use lot babi oil fave posit',
#  'dude go sup',
#  'yoyyooo u know chang permiss drive mac usb flash drive',
#  'gibb unsoldmik hussey',
#  'like talk pa abl dont know',
#  'dun cut short leh u dun like ah fail she quit sad',
#  'unbeliev faglord',
#  'wifehow knew time murder exactli',
#  'ask princess',
#  'great princess think',
#  'nutter cutter ctter cttergg cttargg ctargg ctagg ie',
#  'ok noe ure busi im realli bore msg u oso dunno wat colour choos one',
#  'doesnt g class earli tomorrow thu shouldnt tri smoke ltgt',
#  'superb thought grate u dont everyth u want mean u still opportun happier tomorrow u today',
#  'hope good week check',
#  'im use hope agent dont drop sinc ive book thing year whole boston nyc experi',
#  'thursday night yeah sure thing well work',
#  'free rington wait collect simpli text password mix verifi get usher britney fml',
#  'probabl money worri thing come due sever outstand invoic work two three month ago',
#  'possibl teach',
#  'wonder phone batteri went dead tell love babe',
#  'love smell bu aint tobacco',
#  'get worri derek taylor alreadi assum worst',
#  'hey what charl sorri late repli',
#  'lastest stereophon marley dizze racal libertin stroke win nookii game flirt click themob wap bookmark text wap',
#  'ill give plu said grinul greet whenev speak',
#  'white fudg oreo store',
#  'januari male sale hot gay chat cheaper call nation rate pmin cheap pmin peak stop text call pmin',
#  'love come took long leav zaher got word ym happi see sad left miss',
#  'sorri hurt',
#  'cant feel nauseou im piss didnt eat sweet week caus today plan pig diet week im hungri',
#  'ok lor earli still project meet',
#  'call da wait call',
#  'could ask carlo could get anybodi els chip',
#  'actual send remind today wonder weekend',
#  'peopl see msg think iam addict msging wrong bcoz dont know iam addict sweet friend bslvyl',
#  'hey gave photo regist drive ah tmr wan na meet yck',
#  'dont talk ever ok word',
#  'u wana see',
#  'way school pl send ashley number',
#  'shall fine avalarr hollalat',
#  'went attend anoth two round todaybut still didt reach home',
#  'actual delet old websitenow blog magicalsongsblogspotcom',
#  'k wait chikkuil send aftr ltgt min',
#  'im diet ate mani slice pizza yesterday ugh im alway diet',
#  'ki give kvb acc detail',
#  'oh come ah',
#  'money r lucki winner claim prize text money million give away pptxnormal text rate box wtji',
#  'im realli sorri wont b abl fridayhop u find alternativehop yr term go ok',
#  'congratul ore mo owo wa enjoy wish mani happi moment fro wherev go',
#  'samu shoulder yet',
#  'time think youll need know near campu',
#  'dear matthew pleas call landlin complimentari lux tenerif holiday cash await collect ppm sae tc box skxh',
#  'dun wear jean lor',
#  'sinc side fever vomitin',
#  'kkare colleg',
#  'urgent call landlin complimentari tenerif holiday cash await collect sae tc box hp yf ppm',
#  'better made friday stuf like pig yesterday feel bleh least writh pain kind bleh',
#  'sell well ton coin sell coin someon thru paypal voila money back life pocket',
#  'theyr lot place hospit medic place safe',
#  'get touch folk wait compani txt back name age opt enjoy commun psm',
#  'also ive sorta blown coupl time recent id rather text blue look weed',
#  'sent score sopha secondari applic school think think appli research cost also contact joke ogunrind school one less expens one',
#  'cant wait see photo use',
#  'ur cashbal current pound maxim ur cashin send go pmsg cc po box tcrw',
#  'hey book kb sat alreadi lesson go ah keep sat night free need meet confirm lodg',
#  'chk ur belovd ms dict',
#  'time want come',
#  'awesom lem know whenev your around',
#  'shb b ok lor thanx',
#  'beauti truth graviti read care heart feel light someon feel heavi someon leav good night',
#  'also rememb get dobbi bowl car',
#  'filthi stori girl wait',
#  'sorri c ur msg yar lor poor thing one night tmr ull brand new room sleep',
#  'love isnt decis feel could decid love life would much simpler less magic',
#  'welp appar retir',
#  'sort code acc bank natwest repli confirm ive sent right person',
#  '',
#  'u sure u cant take sick time',
#  'urgent tri contact u today draw show prize guarante call land line claim validhr',
#  'watch cartoon listen music amp eve go templ amp church u',
#  'yo chad gymnast class wan na take site say christian class full',
#  'much buzi',
#  'better still catch let ask sell ltgt',
#  'sure night menu know noon menu',
#  'u want come backa beauti necklac token heart youthat give wife likingb seeno one give thatdont call mei wait till come',
#  'will go aptitud class',
#  'wont b tri sort hous ok',
#  'yar lor wan go c hors race today mah eat earlier lor ate chicken rice u',
#  'haha awesom omw back',
#  'yup thk e shop close lor',
#  'account number',
#  'eh u send wrongli lar',
#  'hey ad crap nite borin without ya boggi u bore biatch thanx u wait til nxt time il ave ya',
#  'ok shall talk',
#  'dont hesit know second time weak like keep notebook eat day anyth chang day sure noth',
#  'hey pay salari de ltgt',
#  'anoth month need chocol weed alcohol',
#  'start search get job daysh great potenti talent',
#  'reckon need town eightish walk carpark',
#  'congrat mobil g videophon r call videochat wid mate play java game dload polyph music nolin rentl',
#  'look fuckin time fuck think',
#  'yo guess drop',
#  'carlo say hell mu ltgt minut',
#  'im offic call ltgt min',
#  'geeee miss alreadi know think fuck cant wait till next year togeth love kiss',
#  'yun ahth ubi one say wan call tomorrowcal look ireneer got bu ubi cresubi tech parkph st wkg daysn',
#  'ugh got ta drive back sd la butt sore',
#  'th juli',
#  'hi im relax time ever get everi day parti good night get home tomorrow ish',
#  'wan come come lor din c stripe skirt',
#  'xma stori peac xma msg love xma miracl jesu hav bless month ahead amp wish u merri xma',
#  'cant dont number',
#  'chang e one next escal',
#  'yetund im class run water make ok pl',
#  'lot happen feel quiet beth aunt charli work lot helen mo',
#  'wait bu stop aft ur lect lar dun c go get car come back n pick',
#  'aight thank comin',
#  ...]

# %%
y
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 5567    1
# 5568    0
# 5569    0
# 5570    0
# 5571    0
# Name: v1, Length: 5572, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(x_preprocessed,y,train_size=0.7)

# %%
x_train
# Out:
# ['im sorri ive join leagu peopl dont keep touch mean great deal friend time even great person cost great week',
#  'lol great im get hungri',
#  'gon na let know co come bak holiday day come dontgettext number',
#  'came hostel go sleep plz call class hrishi',
#  'said u mind go bedroom minut ok sed sexi mood came minut latr wid caken wife',
#  'urgent ur award complimentari trip eurodisinc trav acoentri claim txt di morefrmmob shracomorsglsuplt ls aj',
#  'guy',
#  'im work pleas call',
#  'cute thought friendship necessari share everi secret ur close frnd',
#  'rip get mobil content wwwclubmobycom call polytruepixringtonesgam six download',
#  'im turn phone mom tell everyon cancer sister wont stop call hurt talk cant put see u u get home love u',
#  'win newest harri potter order phoenix book repli harri answer question chanc first among reader',
#  'home work meh',
#  'u got person stori',
#  'hitechn supportprovid assist us custom call email',
#  'esplanad mind give lift co got car today',
#  'plz tell an bslvyl sent via fullonsmscom',
#  'dear voucher holder claim week offer pc go httpwwwetlpcoukexpressoff tsc appli stop text txt stop',
#  'u win music gift voucher everi week start txt word draw tsc wwwidewcom skillgam winaweek age ppermesssubscript',
#  'told number gautham',
#  'im inperialmus listeningth weirdest track ever byleafcutt johnsound like insect molestedsomeon plumbingremix evil men acid',
#  'ask say pleas messag',
#  'k fyi im back parent place south tampa might need deal somewher els',
#  'ok u enjoy ur show',
#  'dun need use dial juz open da browser n surf',
#  'thank rington order refer number x mobil charg tone arriv pleas call custom servic',
#  'also thk fast xy suggest one u dun wan ok go rain leh got gd',
#  'dun believ u thk u told',
#  'make dinner',
#  'go chase run she cross street',
#  'well im computerless time make oreo truffl',
#  'brother transfer ltgt ltgt pa',
#  'wot u thout u gon na call txt bak luv k',
#  'idea guess well work hour suppos leav sinc usual nobodi interest figur shit last second',
#  'send print out da',
#  'like spoil',
#  'get readi ltgt inch pleasur',
#  'oh u must taken real valentin shop first',
#  'guess somebodi know secretli fanci wan na find give us call landlin dateboxessexcmxn pmin',
#  'th gower mate r u man good wale ill b back morrow c u wk msg random',
#  'man bu slow think your gon na get',
#  'sorri ill call later',
#  'forgot work today wan na chat thing ok drop text your free bore etc ill ring hope well nose essay xx',
#  'hi spoke maneesha v wed like know satisfi experi repli toll free ye',
#  'doinghow',
#  'aaooooright work',
#  'anyway serious hit your back otherwis light armand alway shit andor vomit',
#  'perform award calcul everi two monthnot current one month period',
#  'oic saw tot din c found group liao',
#  'ok ill tell compani',
#  'hi home calicut',
#  'come sec there somebodi want see',
#  'im realli sorri wont b abl fridayhop u find alternativehop yr term go ok',
#  'hi engag fixd ltgt th next month know realli shock bthmm njan vilikkamt ws al sudn',
#  'home way',
#  'free game get rayman golf free game arcad st get ur game set repli post save activ press key arcad termsappli',
#  'watch cartoon listen music amp eve go templ amp church u',
#  'know result',
#  'want get laid tonight want real dog locat sent direct ur mob join uk largest dog network txting moan nyt eca pmsgp',
#  'send id password',
#  'meet soon princess ttyl',
#  'prashanthettan mother pass away last night pray famili',
#  'that necessarili respect',
#  'ok found di pierr cardin one look normal cost sale',
#  'lol dont know awesom phone could click delet right want',
#  'thank rington order refer number x mobil charg tone arriv pleas call custom servic colourredtextcolourtxtstar',
#  'peopl game im mall iouri kaila',
#  'freemsg hey im buffi love satisfi men home alon feel randi repli c pix qlynnbv helpp msg send stop stop txt',
#  'today offer claim ur worth discount voucher text ye savamob member offer mobil cs sub unsub repli x',
#  'still west coast haiz take forev come back',
#  'urgent import inform user today lucki day find log onto httpwwwurawinnercom fantast surpris await',
#  'day euro kickoff u kept inform latest news result daili unsubscrib send get euro stop',
#  'k sent',
#  'ask u meet da ge tmr nite',
#  'ive got tea sure flavour',
#  'ha ha ha good joke girl situat seeker',
#  'unni thank dear rechargerakhesh',
#  'freemsg today day readi im horni live town love sex fun game netcollex ltd p per msg repli stop end',
#  'cours guess god got hold right',
#  'thank princess want see nice juici booti',
#  'boy late home father power frndship',
#  'quit late lar ard anyway wun b drivin',
#  'six chanc win cash pound txt csh send cost pday day tsandc appli repli hl info',
#  'tadaaaaa home babe still',
#  'ye da plm ur offic',
#  'hey ive book lesson sun liao',
#  'good even ttyl',
#  'marri local women look discreet action real match instantli phone text match msg cost p stop txt stop bcmsfwcnxx',
#  'pleas attend phone',
#  'thank rington order ref number r mobil charg tone arriv pleas call custom servic',
#  'urgent pleas call landlin abta complimentari tenerif holiday cash await collect sae tc box cwwx ppm',
#  'ugh long day im exhaust want cuddl take nap',
#  'ssi thinl role like sachinjust stand other hit',
#  'pl go ahead watt want sure great weekend abiola',
#  'ill call u mrw ninish address icki american freek wont stop callin bad jen k eh',
#  'carlo say hell mu ltgt minut',
#  'natalja f invit friend repli ye see wwwsmsacunat stop send stop frnd',
#  'romant pari night flight book next year call tsc appli',
#  'im done im sorri hope next space give everyth want rememb furnitur im around move lock lock leav key jenn',
#  'dude saw park car sunroof pop sux',
#  'aight well head',
#  'sfrom train manual show tech processit password reset troubleshoot',
#  'god love limit god grace measur god power boundari may u god endless bless alway ur life gud ni',
#  'import inform orang user xxxxxx today ur lucki day find log onto httpwwwurawinnercom there fantast prizeawait',
#  'pleas give us connect today ltdecimalgt refund bill',
#  'got smaller capac one quit ex',
#  'pl go today ltgt dont want excus',
#  'die accident delet e msg suppos put e sim archiv haiz sad',
#  'saw guy doll last night patrick swayz great',
#  'valu vodafon custom comput pick win prize collect easi call',
#  'havent still waitin usual come back sch oredi',
#  'know lab goggl went',
#  'dear uve invit xchat final attempt contact u txt chat pmsgrcvdhgsuitelandsrowwjhl ldn yr',
#  'rtking pro video club need help inforingtonekingcouk call must club credit redeem wwwringtonekingcouk enjoy',
#  'aight thank comin',
#  'hit move',
#  'co lar im ba dao ok pm lor u never ask go ah said u would ask fri said u ask today',
#  'singl line big mean miss anyth ur best life',
#  'drop tank',
#  'problem babi good time talk call left messag',
#  'oh kkwhere take test',
#  'co darren say consid mah ask',
#  'ltgt w jetton ave forgot',
#  'u still paint ur wall',
#  'free entri wkli comp win fa cup final tkt st may text fa receiv entri questionstd txt ratetc appli over',
#  'u know watchin lido',
#  'dear call',
#  'aight still want get money',
#  'call freephon',
#  'yup im still coffe wif fren fren drove shell give lift',
#  'babe goe day sip cappuccino think love send kiss across sea',
#  'rodger burn msg tri call repli sm free nokia mobil free camcord pleas call deliveri tomorrow',
#  'ok need tell anyth go sleep good night',
#  'want funk ur fone weekli new tone repli tonesu text wwwringtonescouk origin n best tone gbp network oper rate appli',
#  'youll get headach tri figur u trust math promis',
#  'im see cant see mayb reboot ym seen buzz',
#  'k sent',
#  'came look flat seem ok away alot wiv work got woman come',
#  'talk atleast day otherwis miss best friend world shakespear shesil ltgt',
#  'need get',
#  'thank gener date brotha',
#  'im go bath msg next ltgt min',
#  'shall come get pickl',
#  'didnt work oh ok goodnight ill fix readi time wake dearli miss good night sleep',
#  'pathaya enketa maraikara pa',
#  'money issu weigh thank breath easier ill make sure dont regret thank',
#  'great new offer doubl min doubl txt best orang tariff get latest camera phone free call mobileupd free stoptxt tc',
#  'abj serv stay dad alon',
#  'hi test ltgt rd',
#  'late need go n get da laptop',
#  'dawhat plan',
#  'left vagu said would inform person account delay rent discuss hous agenc rent anoth place check onlin place around usc ltgt',
#  'sure result offer',
#  'aight sorri take ten year shower what plan',
#  'sweetheart hope kind day one load reason smile biola',
#  'convey regard',
#  'ha u ju ate honey ar sweet',
#  'slow use biola fne',
#  'come aftr ltdecimalgt clean hous',
#  'privat account statement xxxxxx show unredeem point call identifi code expir',
#  'come friday leav pongaldo get news work place',
#  'posibl dnt live ltgt centuri cm frwd n thnk differ',
#  'ur cashbal current pound maxim ur cashin send cash pmsg cc hgsuiteland rowwjhl',
#  'natalja f invit friend repli ye see wwwsmsacunat stop send stop frnd',
#  'hey morn come ask pa',
#  'easi ahsen got select mean good',
#  'dont search love let love find u that call fall love bcoz u dont forc u fall u know smeon hold u bslvyl',
#  'anyth lor u decid',
#  'guess want alon time could show watch',
#  'uworld site buy qbank buy self assess also',
#  'get dump heap mom decid come low bore',
#  'gon na ring weekend wot',
#  'six chanc win cash pound txt csh send cost pday day tsandc appli repli hl info',
#  'donno scorabl',
#  'exact intent',
#  'sent ur email id soon',
#  'yeah dont see',
#  'dare stupid wont tell anyth hear wont talk',
#  'shop lor rain mah hard leav orchard',
#  'knowwait check',
#  'oh ho first time u use type word',
#  'poor girl cant go one day lmao',
#  'latest news polic station toilet stolen cop noth go',
#  'nokia tone ur mob everi week txt nok st tone free get txtin tell ur friend ptone repli hl info',
#  'good swimsuit allow',
#  'met stranger choos friend long world stand friendship never end let friend forev gud nitz',
#  'ok',
#  'thx well month',
#  'ye pleas swim',
#  'todaysundaysunday holidayso work',
#  'guy go see movi side',
#  'fight world easi u either win lose bt fightng close u dificult u lose u lose u win u still lose',
#  'decid peopl care stuff vote care stuff loser',
#  'uniqu user id remov send stop custom servic',
#  'wot u u weirdo',
#  'gettin bit arti collag mo well tryin ne way got roast min love shall enjoy',
#  'award sipix digit camera call landlin deliveri within day cs box mbp yr warranti ppm p p',
#  'there point hangin mr right he makin u happi',
#  'yeah there bare enough room two us x mani fuck shoe sorri man see later',
#  'lol grr mom take forev prescript pharmaci like minut away ugh',
#  'welcom pleas repli age gender begin eg',
#  'hello news job make wait fifth week yeah im woozl weasel exet still home',
#  'doc appoint next week im tire shove stuff ugh couldnt normal bodi',
#  'that cool hell night lem know your around',
#  'know pl open back',
#  'hot n horni will live local text repli hear strt back p per msg netcollex ltdhelpdesk repli stop end',
#  'pleassssssseeeee tel v avent done sportsx',
#  'releas vday shirt u put make bottom half nake instead white underwear',
#  'urgent ur award complimentari trip eurodisinc trav acoentri claim txt di morefrmmob shracomorsglsuplt ls aj',
#  'dun wear jean lor',
#  'hungri buy food good lei mum n yun dun wan juz buy littl bit',
#  'send pic like',
#  'use foreign stamp whatev send',
#  'anyth lor toa payoh got place walk meh',
#  'hi love goe day fuck morn woke drop cell way stair seem alright phew miss',
#  'dun cut short leh u dun like ah fail she quit sad',
#  'oh fuck sake she like tallahasse',
#  'yo sorri shower sup',
#  'mm ask call radio',
#  'urgent pleas call landlin cash luxuri canari island holiday await collect tc sae award maq ppm',
#  'safe trip nigeria wish happi soon compani share moment',
#  'new address applespairsal malarki',
#  'puriti friendship two smile read forward messageit smile see name gud evng musthu',
#  'laptop noe infra slow lar wan fast one',
#  'fantasi footbal back tv go sky gamestar sky activ play k dream team score start saturday regist nowski opt',
#  'hmmmkbut want chang field quickli dai wan na get system administr network administr',
#  'even v good somewhat event laden fill dont worri head ok throat wreck see six',
#  'possess especi first offens',
#  'k call ah',
#  'would great well guild could meet bristol road somewher get touch weekend plan take flight good week',
#  'hello boytoy geeee miss alreadi woke wish bed cuddl love',
#  'lyricalladief invit friend repli ye see wwwsmsacuhmmross stop send stop frnd',
#  'winner valu network custom select receivea prize reward claim call claim code kl valid hour',
#  'ive got ten buck jay noncomitt',
#  'come',
#  'oh god happi see messag day',
#  'okok okthenwhat ur today plan',
#  'want new nokia colour phone deliv tomorrow free minut mobil free text free camcord repli call',
#  'dont thnk wrong call us',
#  'drop em omw back',
#  'u talk',
#  'thankyou much call appreci care',
#  'dice art class thru thank though idea time come tomorrow',
#  'oh realli perform write paper go movi home midnight huh',
#  'hiya stu wot u im much trubl home moment evon hate even u wot hell av done wont u tell text bck pleas luv dan',
#  'tell u headach want use hour sick time',
#  'think chennai well settl',
#  'takin shower yeah ill leav im done',
#  'ultim tor motiv tui achiev korli',
#  'sm ac sun post helloy seem cool',
#  'hi hun im comin nitetel everi im sorri hope u ava goodtimeoli rang melnit ifink mite b sortedbut il explain everythin monlrsx',
#  'uncl atlanta wish guy great semest',
#  'happi birthday may ur dream come true',
#  'haha awesom minut',
#  'wish hold tightli make see import much mean much need life',
#  'hide anythi keep distanc',
#  'want mapquest someth look usf dogwood drive',
#  'ur rington servic chang free credit go clubmobilescom choos content stop txt club stop pwk club po box mk wt',
#  'wait tv show start lor u leh still busi ur report',
#  'cheer messag zogtoriu ive stare phone age decid whether text',
#  'hey cuti goe wale kinda ok like hill shit still avent kill',
#  'take like noon',
#  'updatenow xma offer latest motorola sonyericsson nokia free bluetooth doubl min txt orang call mobileupd calloptoutfq',
#  'k much th fifti',
#  'went ganesh dress shop',
#  'yup next stop',
#  'agre stop thinkin ipad pleas ask macho question',
#  'oh ok didnt know meant yep babi jontin',
#  'u sick still go shop',
#  'wat happen cruis thing',
#  'gud gudk chikku tke care sleep well gud nyt',
#  'ringtonek',
#  'way school pl send ashley number',
#  'camera award sipix digit camera call fromm landlin deliveri within day',
#  'askd u question hour answer',
#  'dear friend sorri late inform today birthday love arpraveesh detail log face book see number ltgt dont miss delici treat',
#  'omg joanna freak she look thru friend find photo she ask stuff myspac havent even log like year',
#  'today system sh get readyal well also deep well',
#  'goin workout lor muz lose e fat',
#  'someth u ate',
#  'remind hr',
#  'remain bro amongst bro',
#  'let go bill miller',
#  'monthli amount terribl pay anyth till month finish school',
#  'go home first lar wait lor put stuff first',
#  'yar lor u noe u use dat rout',
#  'im stuck da middl da row da right hand side da lt',
#  'eat jap done oso aft ur lect wat got lect rite',
#  'babe fuck love know fuck good hear voic need crave cant get enough ador ahmad kiss',
#  'ok prob',
#  'remind get shall',
#  'tell tell one treat hi hi hi',
#  'thanx send home',
#  'per request maangalyam alaipayuth set callertun caller press copi friend callertun',
#  'nosi guess idk react im freak',
#  'guarante award even cashto claim ur award call free stop getstop php',
#  'usf guess might well take car',
#  'tiim dont let hug dont break tear',
#  'stand away doesnt heart ach without dont wonder dont crave',
#  'nottel softwar name',
#  'infact happi new year see',
#  'p per min call germani bt line p per min check planettalkinstantcom info ts cs text stop opt',
#  'work ah den plu lor u workin oso rite den go orchard lor place go liao',
#  'messag import inform user today lucki day find log onto httpwwwurawinnercom fantast surpris await',
#  'she current scotland',
#  'ill text carlo let know hang',
#  'lol u come idea',
#  'true lov n care wil nevr go unrecogn though somon often make mistak valu definitli undrstnd start miss',
#  'forward free entri weekli comp send word enter tc wwwtextcompcom',
#  'lol oop sorri fun',
#  'themobyo yo yoher come new select hot download member get free click open next link sent ur fone',
#  'bruce b down amp fletcher',
#  'hello per request ltgt rs transfer',
#  'life style garment account pleas',
#  'arun u transfr amt',
#  'burger king wan na play footi top stadium get burger king st sept go larg super cocacola walk winner',
#  'want tel u one thing u mistak k messag sent',
#  'boy love gal propsd bt didnt mind gv lv lttr bt frnd threw thm boy decid aproach gal dt time truck speed toward gal wn hit girld boy ran like hell n save ask hw cn u run fast boy repli boost secret energi n instantli girl shout energi n thi live happili gthr drink boost evrydi moral stori hv free msgsd gud ni',
#  'kind took garag centr part exhaust need replac part order n take fix tomo morn',
#  'im love im excit day spend make happi',
#  'dnt wnt tlk wid u',
#  'otherwis part time job natuit',
#  'tunji how queen wish great day abiola',
#  'messag truro hospit ext phone phone side',
#  'contract mobil mnth latest motorola nokia etc free doubl min text orang tariff text ye callback remov record',
#  'ye appt',
#  'even brother like speak treat like aid patent',
#  'come lt n pass lar',
#  'haha got fast lose weight thk muz go month den got effect geelat go aust put bk e weight',
#  'ur chanc win cash everi wk txt play tsc wwwmusictrivianet custcar xpwk',
#  'ooooooh forgot tell u get yovil phone',
#  'open door',
#  'come friday leav pongaldo get news work place',
#  'u need presnt alway bcz u cant mi love jeevithathil irulina neekunna prakasamanu sneham prakasam ennal prabha mn prabha islov got dont mi',
#  'dude fakemi frnd got money tht im reffer uif u member wit mail link u vl credit ltgt rs il geti ltgt rsi draw acc wen ltgt rs',
#  'goldvik invit friend repli ye see wwwsmsacugoldvik stop send stop frnd',
#  'call germani penc per minut call fix line via access number prepay direct access',
#  'im cool ta luv vtire caus doin load plan wk got social servic inspect nurseri take care spk sn x',
#  'ye princess want catch big strong hand',
#  'free st week nokia tone ur mob everi week txt nokia get txting tell ur mate wwwgetzedcouk pobox wwq normpton',
#  'hey dont forget mine possess properti mmm childish smile',
#  'send number give repli tomorrow morn said like ok',
#  'wat time finish',
#  'reali sorryi dont recognis number confus r u pleas',
#  'ok april cant wait',
#  'hurri ive weeddefici like three day',
#  'still grinder',
#  'thk em find wtc far weiyi goin e rest dunno yet r ur goin dinner den might b abl join',
#  'welcom select servic ad benefit call special train advisor free mobil diall',
#  'ill call even ill idea',
#  'sweet well princess pleas tell like dislik bed',
#  'mobi pub quizwin high street prize u know new duchess cornwal txt first name unsub stop sp arrow',
#  'im eatin lor goin back work soon e mountain deer show huh watch b liao nice',
#  'sad stori man last week bday wife didnt wish parent forgot n kid went work even colleagu wish',
#  'ye complet formclark also utter wast',
#  'kkgoodstudi well',
#  'unless situat go gurl would appropri',
#  'wan na laugh tri chitchat mobil logon txting word chat send cm po box london wa zf pmsg rcvd',
#  'show wot say could u c dust',
#  'im glad follow dream',
#  'ok ksri knw sivatat askd',
#  'er yep sure prop',
#  'home alway chat',
#  'love cuddl want hold strong arm right',
#  'yeah open chat click friend list make list easi pie',
#  'go write ccna exam week',
#  'wat time liao still got',
#  'honey pl find much sell predict nigeria mani time use import repli monday',
#  'boy sweet word left morn sigh goe day love start studi',
#  'goodnight da thangam realli miss u dear',
#  'lem know swing pick im free basic time semest',
#  'trip ok quit tire lor uni start today ok co im take modul ju concentr final yr project',
#  'finish work yet someth',
#  'ur luck love someon ur fortun love one love u',
#  'that cool gentleman treat digniti respect',
#  'hi ami send free phone number coupl day give access adult parti',
#  'might ax well im',
#  'lor ya go dinner togeth',
#  'also where piec',
#  'u think girl propos u today se ur bloodi funki shit fuck faceasssssholeee',
#  'er',
#  'realli tot ur paper end long ago wat u copi ju got use u happi lar still haf studi',
#  'freemsg havent repli text im randi sexi femal live local luv hear u netcollex ltd p per msg repli stop end',
#  'pleas call custom servic repres freephon ampm guarante cash prize',
#  'dont worri guess he busi',
#  'dear voucher holder claim st class airport loung pass use holiday voucher call book quot st class x',
#  'ok prob ill come lunch',
#  'import custom servic announc call freephon',
#  'ltgt g saw day ago guy want sell wifi ltgt g ltgt that blank',
#  'nice day dear',
#  'want new video phone anytim network min text five pound per week call repli deliveri tomorrow',
#  'give someth drink take doesnt vomit temp might drop unmit howev let know',
#  'okay good problem thanx',
#  'madamregret disturbancemight receiv refer check dlf premaricakindli informedrgdsrakheshkerala',
#  'would im still cozi exhaust last nightnobodi went school work everyth close',
#  'hey inconveni si huh',
#  'dnt worryus ice piec cloth packalso take tablet',
#  'thank yesterday sir wonder hope enjoy burial mojibiola',
#  'pock',
#  'nope watch tv home go v bore',
#  'how thing quick question',
#  'get lion england tone repli lionm mono lionp poli go wwwringtonescouk origin n best tone gbp network oper rate appli',
#  'yo watch movi netflix',
#  'senthil group compani apnt pm',
#  'bognor splendid time year',
#  'ye reg ciao',
#  'thank repli today ur visa come r u still buy gucci bag sister thing easi uncl john also bill realli need think make money later sha',
#  'hey mate how u honeydid u ave good holiday gimmi de gossx',
#  'pleas call immedi urgent messag wait',
#  'sorri vikki im watch olav mandara movi kano trishul theatr wit frnd',
#  'rajipl favour pl convey birthday wish nimya pl today birthday',
#  'nice pub near franki n benni near warner cinema',
#  'pub',
#  'sicomo nolistenedth plaid albumquit gdthe new air hilariousalso boughtbraindancea compofstuff aphex abel',
#  'mm food da',
#  'hi im alway onlin yahoo would like chat someday',
#  'good morn plz call sir',
#  'valentin huh proof fb page ugh im glad realli didnt watch rupaul show tool',
#  'look addi goe back monday suck',
#  'chanc might evapor soon violat privaci steal phone number employ paperwork cool pleas contact report supervisor',
#  'nice waitshould text right im gon na pay ticket ya know',
#  'yeah that fine get ok',
#  'shall book chez jule half eight that ok',
#  'ok tell stay yeah tough optimist thing improv month',
#  'want send someth sell fast ltgt k easi money',
#  'ill min look',
#  'speak cash yet',
#  'miss much im despar record messag left day listen hear sound voic love',
#  'well weather cali great complex great need car move freeli tax outrag great place sad part miss home',
#  'call get chanc plz lt',
#  'hi jon pete ive bin spain recent hav sum dinero left bill said u ur rent mayb interest hav pe around tb jame',
#  'lost help',
#  'yar lor actual quit fast co da ge slow wat haha',
#  'hi email address chang',
#  'nice day impress sensibl went home earli feel fine bore when cant rememb',
#  'oop shower u call hey park garag collaps univers hospit see im crazi stuff like happen',
#  'didnt holla',
#  'ur award citi break could win summer shop spree everi wk txt store skilgm tscswinawkag perwksub',
#  'love ass enjoy doggi style',
#  'tone club sub expir resub repli monoc mono polyc poli weekli p per week txt stop stop msg free stream',
#  'think go honesti road call bank tomorrow tough decis make us great peopl',
#  'wan meet n combin part how da rest da project go',
#  'hmm ill think ok your forgiven',
#  'huh slow tot u reach long ago liao u day leh',
#  'wot u bitch',
#  'toshiba porteg gd',
#  'directli behind abt row behind',
#  'lov line hurt truth',
#  'congrat year special cinema pass call c suprman v matrix starwar etc free bxipw pm dont miss',
#  'marrow wed ltgt aha',
#  'ask sen come chennai search job',
#  'got ta collect da car lei',
#  'hello handsom find job lazi work toward get back net mummi where boytoy miss',
#  'yesher tv alway avail work place',
#  'tee hee lectur cheeri bye bye',
#  'yeah still give ride',
#  'sian aft meet supervisor got work liao u work',
#  'finish liao u',
#  'urgent pleas call landlin complimentari lux costa del sol holiday cash await collect ppm sae tc jame ehrr',
#  'noth meant money enter account bank remov flat rate someon transfer ltgt account ltgt dollar got remov bank differ charg also differb sure trust ja person send account detail co',
#  'win newest harri potter order phoenix book repli harri answer question chanc first among reader',
#  'sorri guess whenev get hold connect mayb hour two ill text',
#  'freemsgfav xma tonesrepli real',
#  'dare ask luck sort car',
#  'collect valentin weekend pari inc flight hotel prize guarante text pari wwwrtfsphostingcom',
#  'love know feel make belli warm wish love shall meet dream ahmad ador kiss',
#  'aight time want come',
#  'hi kindli give us back document submit loan stapati',
#  'mean fat head',
#  'nokia get win free auction take part send nokia hgsuiteland rowwjhl',
#  'wan na gym',
#  'dont use hook',
#  'ur hmv quiz cashbal current maxim ur cashin send hmv pmsg',
#  'machan go gym tomorrow wil come late goodnight',
#  'call time job today ok umma ask speed',
#  'oki',
#  'hello damn christma thing think decid keep mp doesnt work',
#  'phone weirdest auto correct',
#  'meet lunch la',
#  'nt yet chikkusimpl habbahw abt u',
#  'usual bodi take care buy make sure doesnt progress pl continu talk saturday',
#  'how watch resiz',
#  'ha ha pop loo hello hello',
#  'guy car shop flirt got phone number paperwork call text im nervou cours may address call boss tell know may get fire',
#  'leav wif lar wan carri meh heavi da num familiar',
#  'first time histori need comfort luxuri sold price india onionr ltgt petrolr ltgt beerr ltgt shesil ltgt',
#  'u want xma free text messag new video phone half price line rental call free find',
#  'da vijay go talk jaya tv',
#  'pen thing beyond joke wont biro dont master cant ever',
#  'yeah there quit bit left ill swing tomorrow get',
#  'know im lack particular dramastorm detail part im worri',
#  'hmm mani unfortun pic obvious arent hot cake kinda fun tho',
#  'kay sinc alreadi',
#  'pleas da call mistak side sorri da pl da goto doctor',
#  'hey sexi bun told ador loverboy hope rememb thank sister law meatbal grin love babe',
#  'filthi stori girl wait',
#  'babe u want dont u babi im nasti thing filthyguy fanci rude time sexi bitch go slo n hard txt xxx slomsg',
#  'noth got msg frm tht unknown',
#  'dont wait til least wednesday see get',
#  'officewhat mattermsg nowi call break',
#  'wait sch finish ard',
#  'opposit side drop',
#  'winner special select receiv cash award speak live oper claim call ampm cost p',
#  'oi ami parchi na kicchu kaaj kort iccha korch na phone ta tul na plz plz',
#  'bloomberg messag center wait appli futur httpcareer bloombergcom',
#  'fanci shag dointerest sextextukcom txt xxuk suzi txt cost per msg tnc websit x',
#  'uniqu enough find th august wwwareyouuniquecouk',
#  'haha first person gon na ask',
#  'ok im come home',
#  'yar want scold u yest late alreadi got zhong se qing u ask b ask ill go w u lor n u still act real',
#  'cant get da laptop matric card wif lei',
#  'think might give miss teach til twelv lectur two damn work thing',
#  'yago restaur',
#  'aww must nearli deadwel jez iscom todo workand whilltak forev',
#  'thank tesco quit nice gone speak soon',
#  'im back amp pack car ill let know there room',
#  'yup noe leh',
#  'eeri nokia tone u rpli tone titl eg tone dracula titl ghost addamsfa munster exorcist twilight wwwgetzedcouk poboxwwq p',
#  'ok lor msg b u call',
#  'pleas ask macho price rang want someth new use plu interfu blackberri bold ltgt bb',
#  'hey hunonbu goin meet want go meal donyt feel like cuz get last bu homebut he sweet latelyxxx',
#  'hai ana tomarrow come morn ltdecimalgt ill sathi go rto offic repli came home',
#  'ok thk got u wan come wat',
#  'u laugh realli loud u talk spontan u dont care other feel u probabl dear amp best friend goodeven dear',
#  'e time go w u lor',
#  'sorri ill call later',
#  'free st week nokia tone ur mob everi week txt nokia get txting tell ur mate wwwgetzedcouk pobox wwq normpton',
#  'oh yeah diet flew window',
#  'nd time tri contact u u pound prize claim easi call p per min btnationalr',
#  'congrat kanowhr treat maga',
#  'take care financi problemi help',
#  'tomarrow final hear laptop case cant',
#  'done internet connect v slow cant send tri later first thing tomo',
#  'doubt could handl time per night case',
#  'haha kid papa need drug',
#  'k your sure dont consent form v',
#  'ill sch fr dun haf da book sch home',
#  'hope youv settl new school year wishin gr day',
#  'cant feel nauseou im piss didnt eat sweet week caus today plan pig diet week im hungri',
#  'still custom place',
#  'carlo take sweet time usual let know patti donew smoke ill tell haul ass',
#  'sure check yahoo email sent photo yesterday',
#  'ok chines food way get fat your pay lipo',
#  'inde way either',
#  'miss call alert number call left messag',
#  'ya ok dinner',
#  'fuck babe miss alreadi know cant let send money toward net need want crave',
#  'guarante latest nokia phone gb ipod mp player prize txt word collect ibhltd ldnwh pmtmsgrcvd',
#  'rgent nd attempt contact uu call b tcsbcmwcnxx callcost ppm mobilesvari max',
#  'kinda first one get twelv aah speak tomo',
#  'dont think u got think use got good ni',
#  'ok',
#  'oh lk tt den take e one tt end cine lor dun wan yogasana oso',
#  'wow v v impress fun shop',
#  'dont search love let love find u that call fall love bcoz u dont forc u fall u know smeon hold u bslvyl',
#  'tri contact respons offer new nokia fone camcord hit repli call deliveri',
#  'tri call repli sm video mobil min unlimit text free camcord repli call del thur',
#  'ok lor',
#  'thanx birthday alreadi',
#  'well right im gon na get check today steam salespe text want come get',
#  'wen ur lovabl bcum angri wid u dnt take serious coz angri childish n true way show deep affect care n luv kettoda manda nice day da',
#  'could work well reach consensu next meet',
#  'wud never mind u dont miss u dont need u wil realli hurt wen u need amp u dont tell take care',
#  'sm servic inclus text credit pl gotto wwwcomuknet login qxj unsubscrib stop extra charg help comukcm ae',
#  'bother trust answer pl',
#  'thought put back box',
#  'aight rush ill ask jay',
#  'privat account statement show unredeem point call identifi code expir',
#  'how ur paper',
#  'great safe trip dont panic surrend',
#  'know mood today',
#  'free rington wait collect simpli text password mix verifi get usher britney fml',
#  'guess somebodi know secretli fanci wan na find give us call landlin dateboxessexcmxn pmin',
#  'kindli send one flat ltdecimalgt today',
#  'liter bed like ltgt hour',
#  'dear take care reach homelov u lot',
#  'havent decid yet eh',
#  'lol im hot air balloon',
#  'u come pick',
#  'boo how thing im back home littl bore alreadi',
#  'dont know im rape dude poker',
#  'dearm cherthalain case u r come cochin pl call bfore u starti shall also reach accordinglyor tell day u r comingtmorow engag an holiday',
#  'urgent ur guarante award still unclaim call closingd claimcod mm pmmorefrommobilebremovedmobypoboxlsyf',
#  'im fine hope also',
#  'ya ok vikki vl c witin ltgt min il repli u',
#  'oh fine ill tonight',
#  'call make sure dat ive woken',
#  'hi u want join st later meet five call u class',
#  'enter cabin pa said happi bday boss felt special askd lunch lunch invit apart went',
#  'ok ill right later',
#  'lul im gettin juici gossip hospit two nurs talk fat gettin one think she obes oyea',
#  'wan win meetgreet westlif u current tour unbreak untam unkempt text cost p std text',
#  'ahhhhjust woken uphad bad dream u thoso dont like u right didnt know anyth comedi night guess im',
#  'mobil number claim call us back ring claim hot line',
#  'congratul ur award either yr suppli cd virgin record mysteri gift guarante call tsc wwwsmsconet pm approx min',
#  'ree entri weekli comp chanc win ipod txt pod get entri std txt rate tc appli detail',
#  'alrit',
#  'problem renew ill right away dont know detail',
#  'hello madam',
#  'oh thank loti alreadi bought egg',
#  'whenev see still hook',
#  'boooo alway work quit',
#  'awesom text your restock',
#  'great get worri know wonder care person like best life know u r wonder god love',
#  'make squeez ltgt buck dad',
#  'captain vijaykanth comedi captain tvhe drunken',
#  'good night go sleep',
#  'u realli pig leh sleep much dad wake smth eat lunch today',
#  'youv tkt euro cup final cash collect call b pobox ppm',
#  'hope good week check',
#  'pleas call custom servic repres freephon ampm guarante cash prize',
#  'dunno da next show aft toa payoh got',
#  'thought prap meant anoth one goodo ill look tomorrow',
#  'strang watch nd one im bed sweet dream miss u',
#  'im job profil seem like bpo',
#  'sell well ton coin sell coin someon thru paypal voila money back life pocket',
#  'hey want anyth buy',
#  'ok help ask she work tmr',
#  'reciev tone within next hr term condit pleas see channel u teletext pg',
#  'love isnt decis feel could decid love life would much simpler less magic',
#  'nokia get win free auction take part send nokia hgsuiteland rowwjhl',
#  'anyth special',
#  'comput fri essenti part dont keep spare fuck idiot roommat looovvv leav thing run full ltgt',
#  'hey go lo lesson gym',
#  'day work dayexcept saturday sunday',
#  'mm feel sleepi today shall get dear',
#  'accident delet messag resend pleas',
#  'yesterday go home',
#  'tell u call claim prize u enter ur mobil person detail prompt care',
#  'cant believ said mani thing morn realli want say good morn love beauti morn see librari later',
#  'come around ltdecimalgt pm vikkyim otsid nw il come tht time',
#  'thanx time weve spent geva bin mint ur babi want uxxxx',
#  'win winner mr foley ipod excit prize soon keep eye ur mobil visit wwwwincouk',
#  'hey happen de alright',
#  'say hi get ass back south tampa prefer kegger',
#  'hey someth came last min think wun sign tmr hee',
#  'site simul test give tough question test readi',
#  'tot group mate lucki havent repli wat time need leav',
#  'nope wif si lor aft bath dog bath look like go rain soon',
#  'kdo even daurgent',
#  'get ur st rington free repli msg tone gr top tone phone everi week per wk opt send stop',
#  'stayin troubl strangersaw dave day he sort nowstil bloke u gona get girl mrur mum still think get getha',
#  'mobil month u r entitl updat latest colour mobil camera free call mobil updat co free',
#  'lol that differ dont go tri find everi real life photo ever took',
#  'orang custom may claim free camera phone upgrad loyalti call offer end thmarch tc appli optout availa',
#  'got outta class gon na go gym',
#  'still get good',
#  'intrepid duo great time see soon',
#  'winner valu network custom select receivea prize reward claim call claim code kl valid hour',
#  'good morn repair shopth reason im hour',
#  'callin say hi take care bruv',
#  'go write msg put dictionari mode cover screen hand press ltgt gentli remov ur hand interest',
#  'u wana see',
#  'alright took morphin back yo',
#  'that good let thank god pleas complet drug lot water beauti day',
#  'want new video phone anytim network min half price line rental free text month repli call free deliveri',
#  'charg transfer charg withdraw anyhow like',
#  'what want come onlin',
#  'yeah whatev lol',
#  'get readi put excel sub face',
#  'gsoh good spam ladiesu could b male gigolo join uk fastest grow men club repli oncal mjzgroup stop repli stop msgrcvd',
#  'hi babe jordan r u im home abroad lone text back u wan na chat xxsp visionsmscom text stop stopcost p',
#  'yo know anyon ltgt otherwis abl buy liquor guy flake right dont get hold somebodi loko night',
#  'hi babe thank come even though didnt go welli want bed hope see soon love kiss xxx',
#  'everi mondaynxt week vl complet',
#  'call dad oredi',
#  'im alway look excus citi',
#  'wen get spiritu deep that great',
#  'dear voucher holder next meal us use follow link pc enjoy dine experiencehttpwwwvouchmecometlpdiningasp',
#  'got xma radio time get',
#  'special select receiv award call line close cost ppm tc appli ag promo',
#  'fine simpli sit',
#  'text get dont call phone problem',
#  'dont number gon na massiv pain ass id rather get involv that possibl',
#  'shuhui bought ron present swatch watch',
#  'take care n get well soon',
#  'noic text your',
#  'rajipl favour pl convey birthday wish nimya pl today birthday',
#  'otherwis part time job natuit',
#  'leav',
#  'yun buy school got offer plu',
#  'fight world easi u either win lose bt fightng close u dificult u lose u lose u win u still lose',
#  'good even ttyl',
#  'glad talk',
#  'stomach thru much trauma swear cant eat better lose weight',
#  'yesher tv alway avail work place',
#  'true passabl get high score appli phd get year salari make life easier',
#  'ok way railway',
#  'xma prize draw tri contact u today draw show prize guarante call land line valid hr',
#  'ron say fri leh n said ding tai feng cant make reserv said wait lor',
#  'go home liao ask dad pick',
#  'housemaid murder coz man murder ltgt th januari public holiday govtinstituit closedinclud post officeunderstand',
#  'urgent mobil award bonu caller prize final attempt contact u call',
#  'who say hi drugdeal',
#  'farm open',
#  'kkare colleg',
#  'youwhen wil reach',
#  'win year suppli cd store ur choic worth enter weekli draw txt music tsc wwwldewcomsubswinppmx',
#  'shoot im doc wait room',
#  'know friend alreadi told',
#  'swt thought nver get tire littl thing lovabl person cozsomtim littl thing occupi biggest part heart gud ni',
#  'differ style',
#  'messageno responcewhat happend',
#  'da run activ full version da',
#  'dear ok',
#  'aiya discuss later lar pick',
#  'look ami ure beauti intellig woman like u lot know u dont like like dont worri',
#  'yay cant wait parti togeth',
#  'ure welcom caught u use broken english',
#  'haha yeah oz kind shitload',
#  'sure dont mean get',
#  'ummmmmaah mani mani happi return day dear sweet heart happi birthday dear',
#  'guessin aint gon na',
#  'done',
#  'ur paper e morn aft tmr',
#  'mon oki lor haha best cheap n gd food la ex oso oki depend whether wana eat western chines food den u prefer',
#  'ok tell half hr b u come need prepar',
#  'that cool want pleas',
#  'got call tool',
#  'ok happen behav like',
#  'im sorri bout last nite wasnt ur fault spous pmt sumthin u give think u shldxxxx',
#  'fantasi footbal back tv go sky gamestar sky activ play k dream team score start saturday regist nowski opt',
#  'thank love rock',
#  'sex ur mobil free sexi pic jordan text babe everi wk get sexi celeb pocketbabecouk pic wk',
#  'import custom servic announc call freephon',
#  'send logo ur lover name join heart txt love name name mobno eg love adam eve yahoo poboxwwq txtno ad p',
#  'good trip watch rememb get back must decid easter',
#  'yet hadya sapna aunti maneg yday hogidhechinnu full weak swalpa black agidhan',
#  'simpl arithmet percentag',
#  'winner valu network custom hvae select receiv reward collect call valid hour aclpm',
#  'spare power suppli',
#  'u outbid simonwatson shinco dvd plyr bid visit sm acsmsreward end bid notif repli end',
#  'heard u call rude chat privat line cum wan c pic gettin shag text pix end send stop sam xxx',
#  'oh kim watch',
#  'waaaat lololo ok next time',
#  'watch telugu moviewat abt u',
#  'good hear',
#  'ill meet lobbi',
#  'sorri earlier put firesar around talk actual life lol',
#  'nah straight bring bud drink someth that actual littl use straight cash',
#  'hi ya babe x u goten bout scammer get smartthough regular vodafon respond get prem rate msgsubscript no use also bewar',
#  'geeee miss alreadi know think fuck cant wait till next year togeth love kiss',
#  'wont get concentr dear know mind everyth',
#  'hi chikku send nice msg',
#  'like ltgt question',
#  'dont thnk wrong call us',
#  'k roommat also want dubsack anoth friend may also want plan bring extra ill tell know sure',
#  'kyou girl wait recept ah',
#  'doesnt need test',
#  'time u wrkin',
#  'need stop go bed make fuck deal',
#  'go ok na',
#  'sac score big hundredh set batsman',
#  'account refil success inr ltdecimalgt keralacircl prepaid account balanc rs ltdecimalgt transact id kr ltgt',
#  'huh cant thk oredi mani page',
#  'spook mob halloween collect logo pic messag plu free eeri tone txt card spook zed p per logop',
#  'hey im bore im think u wat r u',
#  'omg want scream weigh lost weight woohoo',
#  'left alreadi orchard',
#  'love night xxx',
#  'buy',
#  'im gon na miss u much',
#  'aiyah sorri lor watch tv watch forgot check phone',
#  'think sent text home phone cant display text still want send number',
#  'jay get realli impati belliger',
#  'surli ill give come review',
#  'aiyo pleas got time meh',
#  'u mean u almost done done wif sleep tot u go take nap yup send liao im pick ard smth lor',
#  'havent got da topic yet rite',
#  'tonight mate catch sleep new number way',
#  'that bit weird even suppos happen good idea sure pub',
#  'guy ask get slipper gone last year',
#  'sez how u de arab boy hope u r good give love evri love ya eshxxxxxxxxxxx',
#  'hi wlcome back wonder got eaten lion someth noth much',
#  'gentl babi soon take ltgt inch deep insid tight pussi',
#  'gam gone outstand inning',
#  'bookedth hut also time way',
#  'funer home audrey dad',
#  'hey elain today meet still',
#  'ltgt that guess that easi enough',
#  'mean februari april ill get place stay dont hustl back forth audit season sinc sister move away harlem',
#  'dawhat plan',
#  'gent tri contact last weekend draw show prize guarante call claim code k valid hr ppm',
#  'ya well fine bbdpooja full pimpleseven becom quit blackand ur rite cold wear sweatter',
#  'anyway mani good even u',
#  'wait u lor need feel bad lar',
#  'much fight good nite',
#  'kkwhen go',
#  'home watch tv lor',
#  'anyth lar',
#  'cant pick phone right pl send messag',
#  'urgent mobil award bonu caller prize nd attempt contact call boxqu bt nation rate',
#  'dnt wnt tlk wid u',
#  'got job wiproy get everi thing life year',
#  'thinkin someon good drug',
#  'sm auction brand new nokia auction today auction free join take part txt nokia hgsuiteland rowwjhl',
#  'oop ill let know roommat done',
#  'record indic u mayb entitl pound compens accid claim free repli claim msg stop txt stop',
#  'u come n search tat vidnot finishd',
#  'ki delet contact',
#  'oki',
#  'bit ur smile hppnss drop ur tear sorrow part ur heart life heart like mine wil care u forevr goodfriend',
#  'ard like dat lor juz meet mrt station dun haf come',
#  'ranjith cal drpd deeraj deepak min hold',
#  'ya im referin mei ex wat ah waitin u treat somebodi shld b rich liaoso gd den u dun work frm tmr onward',
#  'rajipl favour pl convey birthday wish nimya pl today birthday',
#  'u attend ur drive lesson mani time wk n day',
#  'gon na ask lol think',
#  'dear matthew pleas call landlin complimentari lux tenerif holiday cash await collect ppm sae tc box skxh',
#  'that fine got enough bud last night least',
#  'beauti truth graviti read care heart feel light someon feel heavi someon leav good night',
#  'call da wait call',
#  'ok da alreadi plan wil pick',
#  'cud u tell ppl im gona b bit l co buse hav gon past co full im still waitin pete x',
#  'taxt massagetiepo argh ok lool',
#  'sorri uncl ill keep touch',
#  'urgent mobil number award prize guarante call land line claim valid hr',
#  'lol take member said aunt flow didnt visit month caus develop ovarian cyst bc way shrink',
#  'mobi pub quizwin high street prize u know new duchess cornwal txt first name unsub stop sp',
#  'may call later pl',
#  'your gon na way specif',
#  'welcom ukmobiled msg free give free call futur mg bill p daili cancel send go stop',
#  'want see pretti pussi',
#  'hello yeah ive got bath need hair ill come im done yeah',
#  'didnt spring come earli yay',
#  'well she big surpris',
#  'tell said eat shit',
#  'two team wait player',
#  'uncl timi help clear car',
#  'pl give food prefer pap slowli load sugar take hour give water slowli',
#  'good night dear sleepwellamptak care',
#  'u sleep go take haha got spi wat onlin check n repli mail lor',
#  'send greet joy happi gr even',
#  'otherwis part time job natuit',
#  'custom place wil cal u sir',
#  'hey free call',
#  'ok',
#  'thank way lost',
#  'honeybe said im sweetest world god laugh amp said waitu havnt met person read msg moral even god crack joke gmgngegn',
#  'hurri home u big butt hang last caller u food done im starv dont ask cook',
#  'esplanad lor els',
#  'hmmmi uncl inform he pay school directli pl buy food',
#  'waqt se pehl naseeb se zyada kisi ko kuch nahi miltazindgi wo nahi jo hum socht hai zindgi wo hai jo ham jeetey hai',
#  'want tell bad feel basic time text late need drug',
#  'samu shoulder yet',
#  'sunshin quiz win super soni dvd record cannam capit australia text mquiz b',
#  'say slowli godi love amp need youclean heart bloodsend ten special peopl amp u c miracl tomorrow itplspl',
#  'dizzamn aight ill ask suitem get back',
#  'free video camera phone half price line rental mth cross ntwk min txt call mobileupd calloptout',
#  'suck got plan yo valentin yo valentin arent',
#  'ola would get back mayb today told direct link us get car bid onlin arrang ship get cut u partnership u invest money ship take care restuwud b self reliant soon dnt worri',
#  'meant apolog text get drug ltgt night',
#  'aight call your close',
#  'sale arsen dartboard good condit doubl trebl',
#  'xma stori peac xma msg love xma miracl jesu hav bless month ahead amp wish u merri xma',
#  'im da bu go home',
#  'free entri weekli comp chanc win ipod txt pod get entri std txt rate tc appli detail',
#  'yet chikkugo room nw im bu',
#  'truekdo u knw di ltgt',
#  'supervisor find one lor thk student havent ask yet tell u aft ask',
#  'yeah sure thing mate haunt got stuff sort im go sound anyway promot hex way dont know number joke',
#  'alway celebr ny famili',
#  'good morn dear great amp success day',
#  'good afternoon gloriou anniversari day sweet j hope find happi content prey think send teas kiss across sea coax imag fond souveni cougarpen',
#  'geniu what brother pl send number skype',
#  'got ltgt',
#  'k ill',
#  'hope wasnt piss rememb gone sister someth',
#  'prof pass paper sem congrat student enna kalaachutaarama prof gud mrng',
#  'time u get',
#  'ok would b love u r sure think wot u want drinkin dancin eatin cinema u wot',
#  'get gandhipuram walk cross cut road right side ltgt street road turn first right',
#  'oop phone die didnt even know yeah like better',
#  'seem unnecessarili hostil',
#  'today go colleg abl atten class',
#  'hi good mornin thanku wish u',
#  'sorri ill call later meet',
#  'hi hope good day better night',
#  'anyth lor',
#  'ok ive sent u da latest version da project',
#  'anyway holla whenev your around need excus go creep peopl sarasota',
#  'oh ok',
#  'sorri ill call later meet sir',
#  'cool text head',
#  'network oper servic free cs visit biz',
#  'ah poor babyhop urfeel bettersn luv probthat overdos work hey go care spk u sn lot lovejen xxx',
#  'aight let know your gon na around usf',
#  'new year plan',
#  'mm ask come enough',
#  'ard lor ok messag lor',
#  'okay soon best',
#  'hahahaus brain dear',
#  'monday next week give full gist',
#  'dont think get away trek long famili town sorri',
#  'sorri ill call later',
#  'u dun drive go sch',
#  'would smoke help us work difficult time',
#  'purchas stuff today mail po box number',
#  'ok im walik ard u wan buy anyth go ur hous',
#  'eat fo lunch senor',
#  'got shitload diamond though',
#  'that fine ill bitch later',
#  'lol yep yesterday alreadi got fireplac anoth icon sit',
#  'msg rajini come',
#  'hard live chat pmin choos girl connect live call cheap chat uk biggest live servic vu bcmwcnxx',
#  'fine thank',
#  'im done oredi',
#  'bangbab ur order way u receiv servic msg download ur content u goto wap bangb tv ur mobil internetservic menu',
#  'dont look back build coat dont want get sick hurri home wear coat gym',
#  'type stuff sing',
#  'text pass collect polyphon rington normal gpr charg appli enjoy tone',
#  'whatev juliana whatev want',
#  'haha sound crazi dunno tahan anot',
#  'marvel mobil play offici ultim spiderman game ur mobil right text spider game send u free ball wallpap',
#  'much r will pay',
#  'normal',
#  'dont give monkey wot think certainli dont mind friend mineal dont sleep wiv wud annoyin',
#  'xy ur car u pick',
#  'mean left earli check co im work',
#  'msg mobil content order resent previou attempt fail due network error queri customersqueriesnetvisionukcom',
#  'u gon na get deu ex',
#  'hi wk ok hol ye bit run forgot hairdress appoint four need get home n shower beforehand caus prob u ham',
#  'ya one slow poo',
#  'deam see onlin shop ask',
#  'cant pick phone right pl send messag',
#  'yup',
#  'tension ahwhat machiani problem',
#  'im say havent explicitli told nora know someon im probabl gon na bother',
#  'romcapspam everyon around respond well presenc sinc warm outgo bring real breath sunshin',
#  'still chanc search hard get itlet tri',
#  'got ta',
#  'aathiwher dear',
#  'yeah fact ask need anyth like hour ago much',
#  'sure night menu know noon menu',
#  'want anytim network min text new video phone five pound per week call repli deliveri tomorrow',
#  'town v import',
#  'never lei v lazi got wat dat day send da url cant work one',
#  'storm msg wen u lift phne u say hello u knw wt real mean hello name girl ye u knw dat girl margaret hello girlfrnd f grahmbel invnt telphon moralon get name person',
#  'urgent tri contact u today draw show prize guarante call land line claim valid hr',
#  'jamster get free wallpap text heart tc appli need help call',
#  'forward pleas call immedi urgent messag wait',
#  'see',
#  'sure night menu know noon menu',
#  'goodmorn today late hr',
#  'sorri mail',
#  'check audrey statu right',
#  'japanes proverb one u none itu must indian version one let none itleav final kerala version one stop none make strike',
#  'see',
#  'special select receiv pound award call line close cost ppm tc appli ag promo',
#  'big chic common declar',
#  'pl confirm time collect chequ',
#  'well join ltgt bu',
#  'number sir',
#  'p alfi moon children need song ur mob tell ur ms txt tone chariti nokia poli chariti poli zed profit chariti',
#  'st andr virgil cream',
#  'borrow ur bag ok',
#  'come slave go shell unconsci avoid make unhappi',
#  'want new nokia colour phone deliveredtomorrow free minut mobil free text free camcord repli call',
#  'upload mine facebook',
#  'take didnt phone callon friday assum wont year',
#  'free top rington sub weekli ringtoneget st week freesend subpoli per weekstop sm',
#  'mila age blond new uk look sex uk guy u like fun text mtalk pptxt st free increment help',
#  'pl need dat slowli vomit',
#  'enjoy watch play footbal basketbal anyth outdoor',
#  'nowaday peopl notixiqu laxinorf opportun bambl entrop ever oblising opt ur book masteriast amplikat fidalf champlaxig think atroci wotz ur opinion junna',
#  'im sure still avail though',
#  'valu custom pleas advis follow recent review mob award bonu prize call',
#  'hello site download song urgent pl',
#  'hear new divorc barbi come ken stuff',
#  'pleas reserv ticket saturday eve chennai thirunelvali tirunelvali chennai sunday evei alreadi see netno ticket availablei want book ticket tackl',
#  'alright well bring see like ltgt min',
#  'dont put phone silent mode ok',
#  'much buzi',
#  'im leav hous',
#  'hi kate even hope see tomorrow bit bloodi babyjontet txt back u xxx',
#  'haha friend tyler liter ask could get dubsack',
#  'thing r good thanx got exam march ive done revis fran still boyf ive got ta interviw exet bit worriedx',
#  'hello ucal wen u finish wrki fanci meetin wiv u tonit need break dabook hr last nite today wrk',
#  'ltgt great loxahatche xma tree burn updat total see star',
#  'santa call would littl one like call santa xma eve call book time',
#  'yup hey one day fri ask miwa jiayin take leav go karaok',
#  'sorri took long omw',
#  'ya nowonion roast',
#  'like di sweater fr mango size alreadi irrit',
#  'sm servic inclus text credit pl goto wwwcomuknet login unsubscrib stop extra charg help po box ip',
#  'u konw waht rael friendship im gving yuo exmpel jsut ese tih msg evrey splle tih msg wrnog bt sitll yuo ra wihtuot ayn mitsak goodnight amp nice sleepsweet dream',
#  'stupidit possibl',
#  'watch lor saw swatch one thk quit ok ard need nd opinion leh',
#  'staffsciencenusedusgphyhcmkteachingpc',
#  'like peopl much shi pa',
#  'good sleep rhythm person establish rhythm bodi learn use want know',
#  'take post come must text happi read one wiv hello carolin end favourit bless',
#  'solv case man found murder ltdecimalgt ltgt afternoon wife call polic polic question everyon wife siri sleep murder took place cook cook garden pick veget housemaid went post offic children went play neighbour went marriag polic arrest murder immedi who repli reason u r brilliant',
#  'guarante award even cashto claim ur award call free stop getstop php rg jx',
#  'uncl g check reward month',
#  'bbq sat mine ish ur welcom come',
#  'sure neighbor didnt pick',
#  'whenwher pick',
#  'sri cant talk phone parent',
#  'mobil month u r entitl updat latest colour mobil camera free call mobil updat co free',
#  ...]

# %%
x_test
# Out:
# ['want talk',
#  'nope c',
#  'yesbut said',
#  'sorri light turn green meant anoth friend want ltgt worth may around',
#  'donno gene someth',
#  'miser dont tell u side effect birth control massiv gut wrench cramp first month didnt sleep last night',
#  'lol right diet everyday cheat anyway im meant fatti',
#  'account number',
#  'u wear',
#  'buy today need c meh',
#  'account xxxxxxxxx show unredeem point claim call identifi code xxxxx expir',
#  'wat ur opinion abt abt charact',
#  'wow healthi old airport rd lor cant thk anyth els ill b bath dog later',
#  'alright thank advic enjoy night ima tri get sleep',
#  'run manag minut need oxygen might resort roller option',
#  'hey go jazz power yoga hip hop kb yogasana',
#  'im wif buy tix lar',
#  'last chanc claim ur worth discount voucher today text shop savamob offer mobil cs savamob pobox muz sub',
#  'k must book huh go yoga basic sunday',
#  'men alway need beauti intellig care love adjust cooper wife law allow one wife',
#  'im leav hous',
#  'guy plan come',
#  'chk ur belovd ms dict',
#  'dont forget though love walk besid watch keep heart warm',
#  'well might come',
#  'nonenowher ikno doesdiscountshitinnit',
#  'sure whenev show fuck gt',
#  'black shirt n blue jean thk c',
#  'write wat',
#  'hey tmr mayb meet yck',
#  'ye princess go make moan',
#  'pleas tell car key purs',
#  'thank subscript rington uk mobil charg month pleas confirm repli ye repli charg',
#  'hello go villag pub either come accordingli ok',
#  'she drinkin im ok',
#  'babe miiiiiiissssssssss need crave geeee im sad without babe love',
#  'sir send group mail check',
#  'sent jd custom servic cum account execut ur mail id detail contact us',
#  'xma stori peac xma msg love xma miracl jesu hav bless month ahead amp wish u merri xma',
#  'arriv see coupl day lt',
#  'happi new year melodi',
#  'summer final fanci chat flirt sexi singl yr area get match repli summer free join optout txt stop help',
#  'night end anoth day morn come special way may smile like sunni ray leav worri blue blue bay gud mrng',
#  'im good think',
#  'squeeeeez christma hug u lik frndshp den hug back u get u r cute u r luvd u r lucki none peopl hate u',
#  'freeday sexi st georg day pic jordantxt pic dont miss everi wk sauci celeb pic c pocketbabecouk wk',
#  'pleas sen kind advic pleas come tri',
#  'meet corpor st outsid gap see mind work',
#  'hey leav friday wait ask superior tell',
#  'what room number wan na make sure im knock right door',
#  'greatest test courag earth bear defeat without lose heartgn tc',
#  'guy kadeem hasnt sell sinc break know one guy he paranoid fuck doesnt like sell without cant til late tonight',
#  'nokia tone ur mob everi week txt nok st tone free get txtin tell ur friend ptone repli hl info',
#  'em olowoyey uscedu great time argentina sad secretari everyth bless',
#  'ello babe u ok',
#  'hope great day',
#  'yeah got list u joanna im feel realli anti social',
#  'petei phone still jenni colleg leannewhat',
#  'thanx u darlinim cool thanx bday drink nite morrow take care c u soonxxx',
#  'r comin back dinner',
#  'hear loud scream ltgt minut caus gyno shove thing dont belong',
#  'u knw di ltgt',
#  'watch tv got new job',
#  'daal r ltgt',
#  'how queen go royal wed',
#  'wat uniform get',
#  'kkadvanc happi pongal',
#  'hi babi ive got back work want see u allday hope didnt piss u phone today u give call xxx',
#  'engalnd telli decid wont let watch mia elliot kiss damn',
#  'lol wtf random btw lunch break',
#  'enjoy shower possess pour u ur love one bcoz world lie golden gift love truli',
#  'done hand dont know mega shop asda count celebr that im',
#  'make girl happi difficult make girl happi u need friend companion lover chef ltgt good listen ltgt organ ltgt good boyfriend ltgt clean ltgt sympathet ltgt athlet ltgt warm ltgt courag ltgt determin ltgt true ltgt depend ltgt intellig ltgt psychologist ltgt pest extermin ltgt psychiatrist ltgt healer ltgt stylist ltgt driver aaniy pudunga venaam',
#  'v nice sheffield tom air opinion categori b use measur ethnic next censu busi transcrib',
#  'oh get even u u',
#  'that rude campu',
#  'hi babe chloe r u smash saturday night great weekend u miss sp visionsmscom text stop stop ptext',
#  'take care sleep wellyou need learn chang lifey need get convinc thati wait convers usget convinc timeyour famili mani sensesrespect overemphasiseor u role life',
#  'free top polyphon tone call nation rate get toppoli tune sent everi week text subpoli per pole unsub',
#  'seriou like proper tongu',
#  'go jurong point crazi avail bugi n great world la e buffet cine got amor wat',
#  'hi spoke maneesha v wed like know satisfi experi repli toll free ye',
#  'love give massag use lot babi oil fave posit',
#  'prepar pleasur',
#  'wot u wan na missi',
#  'marriag function',
#  'smile pleasur smile pain smile troubl pour like rain smile sum hurt u smile becoz someon still love see u smile',
#  'attend noth',
#  'hair cream ship',
#  'real tho suck cant even cook whole electr im hungri',
#  'urgent mobil number award prize guarante call land line claim valid hr',
#  'sorri ill call later',
#  'revers cheat mathemat',
#  'ok im sure time finish tomorrow wan na spend even co would vewi vewi lubli love xxx',
#  'aight lem know what',
#  'still check da',
#  'tuesday night r u real',
#  'pleas call amanda regard renew upgrad current tmobil handset free charg offer end today tel subject ts cs',
#  'nvm im go wear sport shoe anyway im go late leh',
#  'princess kitti shave natur',
#  'ha dont know either clever simpl thing pear day perfect christma',
#  'offic na',
#  'im good movi ok leav hourish',
#  'sent type food like',
#  'k yan jiu liao sat go bugi vill one frm den hop parco nb sun go cine frm den hop orc mrt hip hop',
#  'sweet heart',
#  'boy best get yo ass quick',
#  'let ur heart ur compass ur mind ur map ur soul ur guid u never loos worldgnun sent via waysmscom',
#  'carlosl minut still need buy',
#  'congratul thank good friend u xma prize claim easi call p per minut btnationalr',
#  'k want us come',
#  'askd u question hour answer',
#  'yeah lol luckili didnt star role like',
#  'got ur mail dileepthank muchand look forward lot supportveri less contact hererememb one venugop mentionedtomorrow latei shall tri come till theregoodnight dear',
#  'back work morro half term u c nite sexi passion b go back chat luv dena call minmobsmorelkpoboxhpfl',
#  'omg could snow tonit',
#  'beauti truth express face could seen everyon depress heart could understood love one gud ni',
#  'call like ltgt time oh give us hypertens oh',
#  'wait know wesley town bet hella drug',
#  'good day',
#  'stupidit possibl',
#  'hottest pic straight phone see get wet want xx text pic txt cost p textoper gga xxx',
#  'uve bin award play instant cash call claim everi th player win min optout',
#  'shall start hear',
#  'ding ya break fassyol blacko londn',
#  'great news call freefon claim guarante cash gift speak live oper',
#  'hi babe u r like bed im sorri tonight realli wan na see u tomorrow call love xxx',
#  'okay lor wah like def wont let us go haha say term condit',
#  'ill b go sch mon si need take smth',
#  'havent mu ask u st wat meet lunch den u n meet alreadi lor u wan go ask da ge st confirm w asap',
#  'awesom plan get time like ltgt ill text detail wee bit',
#  'want get laid tonight want real dog locat sent direct ur mob join uk largest dog network bt txting gravel nt eca pmsgp',
#  'appt lttimegt fault u dont listen told u twice',
#  'sm ac sptv new jersey devil detroit red wing play ice hockey correct incorrect end repli end sptv',
#  'ooh got im gon na start belli danc moseley wed u want join cafe',
#  'haha mayb ure rite u know well da feel like someon gd lor u faster go find one gal group attach liao',
#  'chill anoth hr could sleep pain surgic emerg see unfold okay',
#  'sorri ill call later',
#  'that cool day',
#  'need ke qi bore izzit suddenli thk',
#  'pl pl send mail know rel come deliv know cost risk benefit anyth els thank',
#  'understand loss gain work school',
#  'exam februari wish great day',
#  'sea lay rock rock envelop envelop paper paper word',
#  'awesom deal gate charl told last night uh yeah',
#  'aight ill ask roommat',
#  'sif one good partnership go take lead',
#  'great attract brotha',
#  'he realli skateboard despit fact get thrown wind bandag shit arm everi five minut',
#  'moji love word rich day',
#  'yar tot u knew di would happen long ago alreadi',
#  'rightio well arent bright earli morn',
#  'yesterday true true',
#  'sorri ill call later',
#  'kkyesterday cbe',
#  'honestli ive made love cup tea promptli drop key burnt finger get',
#  'hey da cool iknow wellda peril studentfinanci crisisspk u lr',
#  'rememb',
#  'dont want hear philosophi say happen',
#  'interest like',
#  'deep sigh miss realli surpris havent gone net cafe yet get dont miss',
#  'late',
#  'ya nice readi thursday',
#  'e best ur exam later',
#  'noth ju tot u would ask co u ba gua went mt faber yest yest ju went alreadi mah today go ju call lor',
#  'gosh pain spose better come',
#  'free entri weekli comp chanc win ipod txt pod get entri std txt rate tc appli detail',
#  'hi darlin youphon im athom youwanna chat',
#  'r still meet dinner tonight',
#  'let want hous',
#  'u call',
#  'hey chief give bell get need talk royal visit st june',
#  'mode men left',
#  'camera award sipix digit camera call fromm landlin deliveri within day',
#  'make easi pay back ltgt yr say pay back earlier get',
#  'sure dont forgot comei alway touch',
#  'took hooch walk toaday fell splat graze knee everyth stay home see tomorrow',
#  'wat make peopl dearer de happi dat u feel u meet de pain u feel u miss dem',
#  'congratul thank good friend u xma prize claim easi call p per minut btnationalr',
#  'sens foot peni',
#  'vikki come around lttimegt',
#  'head straight',
#  'da good good playerwhi unsold',
#  'kkfrom tomorrow onward start ah',
#  'wont wat wit guy',
#  'hack chat get backdoor entri chat room fraction cost repli neo call subscrib p pm dp bcm box ldn wcnxx',
#  'place man',
#  'student solv cat question xam ltgt ltgt ltgt tell answer u r brilliantthingi got answr',
#  'sppok ur mob halloween collect nokia logop messag plu free eeri tone txt card spook',
#  'could ask carlo could get anybodi els chip',
#  'custom servic announc recent tri make deliveri unabl pleas call reschedul ref',
#  'detroit home snow enjoy',
#  'valu custom pleas advis follow recent review mob award bonu prize call',
#  'oop thk dun haf enuff go check tell',
#  'im guy browsin compulsori',
#  'haha cant tmr forfeit haha',
#  'want new video handset anytim network min half price line rental camcord repli call deliveri tomorrow',
#  'come din c yup cut hair',
#  'noth get msg di name wit differ no',
#  'oic co n si got lunch today dad went dunno whether eat sch wat',
#  'aight text address',
#  'sef dey laugh meanwhil how darl anji',
#  'ok',
#  'ok problem yup im go sch rem correctli',
#  'free messag activ free text messag repli messag word free term condit visit wwwcom',
#  'u studi sch go home anyway ill b go sch later',
#  'actual first time went bed long spoke woke night',
#  'free ring tone text poli everi week get new tone yr wk',
#  'free entri weekli competit text word win tc wwwtxttowincouk',
#  'one joy lifei wake daywith thought somewheresomeon care enough tosend warm morn greet',
#  'got back dislik bed',
#  'tuition hm go one mind',
#  'congrat mobil g videophon r call videochat wid mate play java game dload polyph music nolin rentl',
#  'hi dear call urgnt dont know what problem dont want work problem least tell wate repli',
#  'come karnan car pleas wait till pm directli goto doctor',
#  'aight sound good want come',
#  'make happi',
#  'life face choic toss coin becoz settl question coin air u know heart hope gudni',
#  'dont b floppi b snappi happi gay chat servic photo upload call pmin stop text call',
#  'know thinkin malaria relax children cant handl malaria would wors gastroenter take enough replac loss temp reduc give malaria med vomit self limit ill mean day complet stop',
#  'search happi main sourc unhappi accept life way come u find happi everi moment u live',
#  'ok prob take ur time',
#  'oh well c u later',
#  'think ask gym excus lazi peopl jog',
#  'get ok',
#  'ill text creepi like wont think forgot',
#  'pa tell went bath',
#  'doubl min doubl txt price linerent latest orang bluetooth mobil call mobileupd latest offer calloptoutlf',
#  'rock yr chik get filthi film xxx pic yr phone rpli filth saristar ltd e yt p per day stop cancel',
#  'lol nah wasnt bad thank good b home quit realiti check how ur day u anyth websit',
#  'u secret admir reveal think u r special call opt repli reveal stop per msg recd cust care',
#  'u definit need modul e human di sem izzit u wan take modul st',
#  'mmmmmmm snuggl deep content sigh whisper fuck love much bare stand',
#  'help u swoop pick u wherev ur bird r meet u want',
#  'crazi ar he marri like gd look guy fren like say he korean leona fave dun thk aft think mayb prob ill go',
#  'yep derek hous see sunday lt',
#  'wiskey brandi rum gin beer vodka scotch shampain wine kudiyarasu dhina vaazhthukk',
#  'yeah abl ill text im readi meet',
#  'wyli tampa sarasota',
#  'ok ask abt e movi u wan ktv oso',
#  'en chikku nang bakra msg kalstiyathen teacoffe',
#  'know dat feelin pete wuld get em nuther place nuther time mayb',
#  'finish alreadi yar keep say mushi embarrass ok',
#  'urgent tri contact u today draw show prize guarante call land line claim j po boxcpm',
#  'want lick pussi',
#  'cha quiteamuz thatscool babe',
#  'hot live fantasi call p per min ntt ltd po box croydon cr wb nation rate call',
#  'aunti huai juan never pick phone',
#  'dont know jack shit anyth id sayask someth help want pretend text whatev respons hypotheticalhuagauahahuagahyuhagga',
#  'wot u j',
#  'ye one woman man pleas tell like dislik bed',
#  'never tri alon take weight tear come ur heart fall ur eye alway rememb stupid friend share bslvyl',
#  'oh right ok ill make sure load work day got realli nasti cough today dri n shot realli help',
#  'dun b sad dun thk abt alreadi concentr ur paper k',
#  'sever sir',
#  'im wait till bu pick',
#  'let know chang next hr even appendix age rang howev imposs chill let know hr',
#  'life strict teacher bcoz teacher teach lesson amp conduct exam life first conduct exam amp teach lesson happi morn',
#  'whore unbeliev',
#  'that cool like photo sexi',
#  'two letter copi co one messag speak soon',
#  'dear angri busi dear',
#  'hi darlin hope nice night wish come cant wait see love fran ps want dirti anal sex want man gang bang',
#  'nvm ok',
#  'hi yiju meet u tmr',
#  'much u tri get',
#  'happi new year u',
#  'big differ ltgt versu ltgt everi ltgt hr',
#  'actual nvm got hella cash still ltgt ish',
#  'dorothykiefercom bank granit issu strongbuy explos pick member nasdaq symbol cdgt per',
#  'boo im way mom she make tortilla soup yummmm',
#  'hey gorgeou man work mobil number good one babe squishi mwah',
#  'ok darlin supos ok worri muchi film stuff mate babysit call therexx',
#  'new mobil must go txt nokia collect todayfrom wwwtcbiz optout gbpmtmsg',
#  'pleas call custom servic repres freephon ampm guarante cash prize',
#  'said look pretti wif long hair wat thk he cut quit short leh',
#  'check choos babe video smsshsexnetun fgkslpopw fgkslpo',
#  'argh g spotti anyway thing rememb research provinc sterl problemfre place look',
#  'money r lucki winner claim prize text money million give away pptxnormal text rate box wtji',
#  'ok knacker came home went sleep good full time work lark',
#  'receiv understood n act upon',
#  'hi wont b ard christma enjoy n merri xma',
#  'get librari',
#  'r outsid alreadi',
#  'also know lunch menu da know',
#  'worri hope photo shoot went well spif fun workag',
#  'pl send address sir',
#  'dont anybodi number still havent thought tact way ask alex',
#  'mostli like',
#  'aiyah u ok alreadi lar e nydc wheellock',
#  'room',
#  'make babi yo tho',
#  'got divorc lol she',
#  'wifehow knew time murder exactli',
#  'dont make ne plan nxt wknd coz want us come ok',
#  'hi darlin ive got back realli nice night thank much lift see u tomorrow xxx',
#  'good word word may leav u dismay mani time',
#  'go goodno problembut still need littl experi understand american custom voic',
#  'everyth weather keep extra warm cold noth seriou pl lot vitamin c',
#  'aslamalaikkuminsha allah tohar beeen muht albi mufti mahfuuzmean',
#  'final readi fyi',
#  'im home',
#  'ok way home hi hi',
#  'urgent call landlin complimentari ibiza holiday cash await collect sae tc po box sk wp ppm',
#  'k sent',
#  'free rington text first poli text get true tone help st free tone xpw end txt stop',
#  'plan yet',
#  'ok',
#  'help propos go back tomorrow',
#  'kate jackson rec center ish right',
#  'huh also mani mistak',
#  'ok',
#  'ju finish watch tv u',
#  'jesu christ bitch im tri give drug answer fuck phone',
#  'isnt frnd neces life imagin urself witout frnd hwd u feel ur colleg watll u wth ur cell wat abt function thnk abt event espel care miss amp irrit u wrd dearlov frnd wthout u cant live jst takecar goodmorn',
#  'de ask like',
#  'uh head dont much left',
#  'okay name ur price long legal wen pick u ave x am xx',
#  'send resum',
#  'call ltgt min that ok',
#  'doubl min txt month free bluetooth orang avail soni nokia motorola phone call mobileupd calloptoutndx',
#  'u ned convinc tht possibl witot hurt feel main',
#  'go join tomorrow',
#  'rose need water season need chang poet need imaginationmi phone need ur sm need ur love frndship forev',
#  'hey go quit soon xuhui work till end month',
#  'sorri meet ill call later',
#  'babe talk think good boy miss love',
#  'ye dont care caus know',
#  'one small prestig problem',
#  'suppos wake gt',
#  'studi ill free next weekend',
#  'fine imma get drink somethin want come find',
#  'confirm eat esplanad',
#  'missionari hook doggi hook stand',
#  'want send virtual hug need one',
#  'ok msg u b leav hous',
#  'cool want go kappa meet outsid mu',
#  'pain urin thing els',
#  'search good dual sim mobil pa',
#  'she good r u work',
#  'havent eaten day im sit stare juici pizza cant eat med ruin life',
#  'oh forward messag thought send',
#  'pl dont play other life',
#  'cant u tri new invent flyim joke',
#  'consid wall bunker shit import never play peac guess place high enough dont matter',
#  'oh shut omg yesterday dream kid boy piss kid boy even told mark dream chang diaper caus im get owe face',
#  'tick tick tick could die loneli know pout stomp feet need',
#  'annoy isnt',
#  'what oga left phone home saw ur messag hope good great weekend',
#  'stop wonder wow ever go stop tming tm whenev want mine laugh',
#  'cinema plu drink appeal tomo fr thriller director like mac',
#  'hi yiju regard textbook intro algorithm second edit im sell',
#  'im solihul want anyth',
#  'aight text tonight well see what',
#  'will go app class',
#  'septemb',
#  'yesfrom last week im take live call',
#  'k make sens btw carlo difficult guy gon na smoke go pick second batch get ga',
#  'best line said love wait till day forget u day u realiz u forget gn',
#  'velli good ye pleas',
#  'today im workin free oso gee thgt u workin ur fren shop',
#  'sent de webadr gete salari slip',
#  'much textin bout',
#  'dont worri well finish march ish',
#  'feb ltgt love u day send di ur valu frnd evn come back ull gt marri person u luv u ignor di u lose ur luv evr',
#  'sorri ill call later',
#  'know taj mahal symbol love lesser known fact mumtaz shahjahan th wife wife shahjahan kill mumtaz husband marri mumtaz die ltgt th deliveri marri mumtaz sister question aris hell love great hari',
#  'there ring come guy costum gift futur yowif hint hint',
#  'ur go bahama callfreefon speak live oper claim either bahama cruis cash opt txt x',
#  'u still go mall',
#  'im arestaur eat squid wan na dosometh late',
#  'daddi take good care',
#  'outsid offic take',
#  'born god said oh anoth idiot born',
#  'march end readi call sure problem capit never complet far how work ladi',
#  'ya take ure practic lesson start june',
#  'realli need kiss u miss u babi ur babi eva',
#  'watch tv got new job',
#  'work mon thur sat cant leh book liao day u free',
#  'actual send remind today wonder weekend',
#  'that ebay might less elsewher',
#  'got arrest possess shit lttimegt pm',
#  'pl dont restrict eat anythin like next two day',
#  'wish great semest',
#  'e msg ju u said thank gift',
#  'earli bird purchas yet',
#  'one talk',
#  'superb thought grate u dont everyth u want mean u still opportun happier tomorrow u today',
#  'reach home tire come tomorro',
#  'design softwar develop may get chennai',
#  'babe think got ur brolli left english wil bring mrw u luv franxx',
#  'ah well confus thing doesnt',
#  'send new number',
#  'dont plan stay night prolli wont back til late',
#  'lol ye friendship hang thread caus u wont buy stuff',
#  'hey project start aha da',
#  'smile right go world wonder smile think crazi keep away grin',
#  'privat account statement show unredeem point call identifi code expir',
#  'say slowli godi love amp need youclean heart bloodsend ten special peopl amp u c miracl tomorrow itplspl',
#  'sound better even im costum im sure time finish tomorrow txt end',
#  'wifehow knew time murder exactli',
#  'pain couldnt come wors time',
#  'date servic ask contact u someon shi call reveal pobox uz p',
#  'im wonder right',
#  'twink bear scalli skin jock call dont miss weekend fun call pmin stop text call nat rate',
#  'ive reach home n bath liao u call',
#  'sunshin hol claim ur med holiday send stamp self address envelop drink us uk po box bray wicklow eir quiz start saturday unsub stop',
#  'think tantrum finish yeah ill point',
#  'aight text your back mu ill swing need somebodi get door',
#  'doubl min txt month free bluetooth orang avail soni nokia motorola phone call mobileupd calloptoutndx',
#  'chikku nt yet ya im free',
#  'sorri pain ok meet anoth night spent late afternoon casualti mean havent done stuffmoro includ time sheet sorri',
#  'im boat still mom check yo im half nake',
#  'congratul u claim vip row ticket c blu concert novemb blu gift guarante call claim tsc wwwsmsconet costmax',
#  'goodnight sleep well da pleas take care pa pleas',
#  'well obvious peopl cool colleg life went home',
#  'waiti come ltgt min',
#  'new theori argument win situat lose person dont argu ur friend kick amp say im alway correct',
#  'still work go onit small hous',
#  'reach home call',
#  'yo im parent gettin cash good news pick downstem',
#  'oh wow that gay firmwar updat help',
#  'want anytim network min text new video phone five pound per week call repli deliveri tomorrow',
#  'wont move morphin',
#  'time come later',
#  'dun need pick ur gf',
#  'k ill drinkpa need sr model pl send mail id pa',
#  'plan manag',
#  'mani thing antibiot use chest abdomen gyna infect even bone infect',
#  'monthli password wap mobsicom use wap phone pc',
#  'sorri cant help',
#  'yar lor keep rain non stop u wan go elsewher',
#  'fun fact although would think armand would eventu build toler shit consid much smoke get fuck like hit',
#  'u wan come dinner tonight',
#  'usualiam fine happi amp well',
#  'bring got',
#  'lol pleas actual send pic right wan na see pose comb hair dryer someth',
#  'omg one thing anoth cat worm bad day end',
#  'idc get weasel way shit twice row',
#  'mobil mth updat latest orang cameravideo phone free save free textsweekend call text ye callback orno opt',
#  'aight fuck ill get later',
#  'opinion jada kusruthi lovabl silent spl charact matur stylish simpl pl repli',
#  'guy bitch act like id interest buy someth els next week gave us free',
#  'work right',
#  'okay book alreadi includ one bugi',
#  'buy space invad chanc win orig arcad game consol press game arcad std wap charg see ocoukgam term set purchas',
#  'thank lot wish birthday thank make birthday truli memor',
#  'multimedia messag email',
#  'that troubl class go well your due dodgey one expect mine tomo see recoveri time place',
#  'eat shit wait ur monkey face bitch u asshol',
#  'sorri c ur msg yar lor poor thing one night tmr ull brand new room sleep',
#  'sorri im get feel realli bad total reject kinda thing',
#  'know god creat gap finger one made come amp fill gap hold hand love',
#  'basket gettin full might tonight',
#  'u fix teethif asapok take care',
#  'hm good morn headach anyon',
#  'k actual guy meet sunoco howard right way',
#  'yar lor wan go c hors race today mah eat earlier lor ate chicken rice u',
#  'cocksuck make feel better ipad worthless garbag novelti item feel bad even want one',
#  'lol busi',
#  'hi neva worri bout da truth coz truth lead ur heart least uniqu person like u deserv sleep tight morn',
#  'dont hesit know second time weak like keep notebook eat day anyth chang day sure noth',
#  'long fuckin showr',
#  'wish great day moji told offer alway speechless offer easili go great length behalf stun exam next friday keep touch sorri',
#  'tell reach',
#  'wait call sir',
#  'well offici philosoph hole u wan na call home readi save',
#  'well ball time make call',
#  'r e meet tmr',
#  'alex say he ok ok',
#  'vl bcum difficult',
#  'date sunday',
#  'dont necessarili expect done get back though im headin',
#  'hey kate',
#  'hai priya right doctor said pa',
#  'hiya how go sunni africa hope u r avin good time give big old silver back big kiss',
#  'dear good morn feel dear',
#  'ye saw messag',
#  'dont shall buy one dear',
#  'ye mani sweet',
#  'ur lectur',
#  'rofl true name',
#  'wont touch permiss',
#  'drive read need write',
#  'idea soon get convert live',
#  'want say holi shit guy werent kid bud',
#  'fact your clean show know im upset prioriti constantli want',
#  'shall send exe mail id',
#  'good even',
#  'sat right okay thank',
#  'shb b ok lor thanx',
#  'sen told go join uncl financ cbe',
#  'dont prize go anoth custom tc wwwtcbiz pmin polo ltd suit london wj hl pleas call back busi',
#  'that u haf keep busi',
#  'u workin overtim nigpun',
#  'avail im like right around hillsborough amp ltgt th',
#  'u win music gift voucher everi week start txt word draw tsc wwwldewcom skillgamewinaweek ageppermesssubscript',
#  'guarante latest nokia phone gb ipod mp player prize txt wordcollect tcllc nyusa pmt msgrcvd',
#  'need th im campu atm could pick hour two',
#  'joy father john john joy father u an th hav ltgt iq ti ia question tri answer',
#  'free text messag valid decemb',
#  'congratul thank good friend u xma prize claim easi call p per minut btnationalr',
#  'eastend tv quiz flower dot compar violet e tulip f lili txt e f chanc win cash wkentp',
#  'hope arnt piss id would realli like see tomorrow love xxxxxxxxxxxxxx',
#  'sorri abl get see morn',
#  'want kiss feel next',
#  'noth smsing u n xy lor sorri lor da guy neva c u person sort know u lor u wan meet xy ask bring u along next meet',
#  'good thing im get connect bw',
#  'ive search right word thank breather promis wont take help grant fulfil promis wonder bless time',
#  'keep away like',
#  'sorri ill call later',
#  'start dont stop pray good idea anyth see help guy ill forward link',
#  'told come wednesday',
#  'got take take part wrc ralli oz u lucozad energi text ralli le p see pack lucozadecoukwrc itcould u',
#  'oh mr sheffield wan na play game okay your boss im nanni give rais ill give one',
#  'ah see lingo let know wot earth finish make',
#  'hope feel great pl fill abiola',
#  'remain unconvinc isnt elabor test willpow',
#  'ta job avail let know pleas co realli need start work',
#  'k ill work someth',
#  'problem spend lot qualiti time togeth',
#  'u wan haf lunch im da canteen',
#  'take part mobil survey yesterday text use howev wish get txt send txt tc wwwtxtcom p',
#  'v fan',
#  'im realli realli broke oh amount small even ltgt',
#  'u get pic msg phone',
#  'see finish load loan pay',
#  'dunno let go learn pilat',
#  'yup izzit still rain heavili co im e mrt cant c outsid',
#  'weird know one point',
#  'text banneduk see cost p textoper gga xxx',
#  'sorri got late start way',
#  'east coast',
#  'sir goodmorn free call',
#  'boy love gal propsd bt didnt mind gv lv lttr bt frnd threw thm boy decid aproach gal dt time truck speed toward gal wn hit girld boy ran like hell n save ask hw cn u run fast boy repli boost secret energi n instantli girl shout energi n thi live happili gthr drink boost evrydi moral stori hv free msgsd gud ni',
#  'ive call hope lr malaria know miss guy miss bani big pl give love especi great day',
#  'ive reach home final',
#  'sure stomach',
#  'sound great home',
#  'wat time u wan meet later',
#  'yo yo yo byatch whassup',
#  'storm msg wen u lift phne u say hello u knw wt real mean hello name girl ye u knw dat girl margaret hello girlfrnd f grahmbel invnt telphon moralon get name person',
#  'right ill make appoint right',
#  'send ur friend receiv someth ur voic speak express childish naughti sentiment rowdi ful attitud romant shi attract funni ltgt irrit ltgt lovabl repli',
#  'say he quit leasttim day wudnt take much notic nah didnt mind gon na see want come taunton tonight u tell',
#  'da vijay go talk jaya tv',
#  'fyi im take quick shower epsilon like ltgt min',
#  'today vodafon number end select receiv award number match call receiv award',
#  'sure sinc parent work tuesday dont realli need cover stori',
#  'yo carlo friend alreadi ask work weekend',
#  'pl clarifi back open return ticket prepon go back kerala',
#  'way ur home',
#  'great im church holla get',
#  'im park next mini come today think',
#  'love wine dine ladi',
#  'bishan lar nearer need buy earli co buy got ta park car',
#  'someon contact date servic enter phone becausethey fanci find call landlin pobox wrg p',
#  'brand new mobil music servic live free music player arriv shortli instal phone brows content top artist',
#  'hi di yiju meet pm esaplanad tonight',
#  'im realli still tonight babe',
#  'huh fast dat mean u havent finish paint',
#  'dear chechi talk',
#  'cool come havent wine dine',
#  'ill text drop x',
#  'tomarrow want got court ltdecimalgt come bu stand',
#  'webpag avail',
#  'nofew hour beforew hair cut',
#  'ye im small kid boost secret energi',
#  'kthen special',
#  'ok day make dinner tonit invit',
#  'releas anoth italian one today cosign option',
#  'mayb could get book tomo return immedi someth',
#  'thank youv wonder',
#  'im bu love',
#  'cant keep talk peopl sure pay agre price pl tell want realli buy much will pay',
#  'hen night go swing',
#  'ga station go',
#  'aight close still around alex place',
#  'dont know u u dont know send chat let find pmsg rcvd hgsuitelandsrowwjhl ldn year',
#  'sorri go home first daddi come fetch later',
#  'mind blastin tsunami occur rajnik stop swim indian oceand',
#  'im done',
#  'much get',
#  'datingi two start sent text talk sport radio last week connect think coincid',
#  'what featheri bowa someth guy dont know',
#  'heard week',
#  'good even sir al salam wahleykkumshar happi newsbi grace god got offer tayseertissco joinedhop fineinshah allahmeet sometimerakheshvisitor india',
#  'hello sort town alreadi dont rush home eat nacho let know eta',
#  'im come home dinner',
#  'start send blackberri torch nigeria find buyer melik month tell dad buy bb anyon oh',
#  'love start attractioni feel need everi time around mesh first thing come thoughtsi would start day end hersh everi time dreamlov everi breath namemi life happen around hermi life name heri would cri herwil give happi take sorrowsi readi fight anyon heri love craziest thing herlov dont proov anyon girl beauti ladi whole planeti alway sing prais herlov start make chicken curri end maki sambarlif beauti thenwil get everi morn thank god day mei would like say lotwil tell later',
#  'min later k',
#  'he appar bff carli quick',
#  'new textbuddi chat horni guy ur area p free receiv search postcod gaytextbuddycom txt one name',
#  'drug abl eat',
#  'hmmm mayb tri e shoppin area one forgot e name hotel',
#  'ohi ask fun hahatak care',
#  'thank messag realli appreci sacrific im sure process direct pay find way back test tomorrow im class wonder day',
#  'good even sir hope nice day want bring notic late pay rent past month pay ltgt charg felt would inconsider nag someth give great cost that didnt speak howev recess wont abl pay charg month henc askin well ahead month end pleas help thank everyth',
#  'ok lor',
#  'dint slept afternoon',
#  'pick variou point go yeovil motor project hour u take home max easi',
#  'noe ben go',
#  'pl send correct name da',
#  'sleepingand surf',
#  'ey calm downon theacus itxt u co iwana know wotu r doin thewend haventcn u agesr ur neth satlov j xxx',
#  'seem unnecessarili affection',
#  'send email mind ltgt time per night',
#  'think go finn come',
#  'yup wun believ wat u realli neva c e msg sent shuhui',
#  'ye princess want make happi',
#  'stupidit possibl',
#  'got new job bar airport satsgettin per hour mean lie keep touch',
#  'what happen gotten job begun registr perman resid',
#  'dhoni luck win big titleso win',
#  'hey look like wrong one kappa guy number still phone want text see he around',
#  'im done studyn librari',
#  'later guess needa mcat studi',
#  'rose redr bloodblood heartheart u u send ti ur friend includ u like u get back u r poor relat u need support u r frnd mani luv u pray god marri u tri',
#  'ok',
#  'call tell infront call',
#  'way',
#  'know grumpi old peopl mom like better lie alway one play joke',
#  'u subscrib best mobil content servic uk per ten day send stop helplin',
#  'want final lunch today',
#  'ur chanc win wkli shop spree txt shop tsc wwwtxtshopcom custcar xpwk',
#  'hmm yeah groov im look forward pound special',
#  'ok come ur home half hour',
#  'xma new year eve ticket sale club day till pm thur fri sat night week theyr sell fast',
#  'u secret admir look make contact ufind rreveal think ur specialcal stopsm',
#  'hiya good day spoken sinc weekend',
#  'ask around there lot term mid',
#  'need coz never go',
#  'chang e one next escal',
#  'wish famili merri x ma happi new year advanc',
#  'forgot ask smth there card da present lei want write smth sign',
#  'ever green quot ever told jerri cartoon person irrit u alway one love u vri much fail express gud nyt',
#  'pl pl find aunt nike',
#  'see requir pleas',
#  'get chicken broth want ramen unless there dont know',
#  'urgent week free membership prize jackpot txt word claim tc wwwdbuknet lccltd pobox ldnwarw',
#  'still tonight',
#  'much buzi',
#  'goodmorn today late ltdecimalgt min',
#  'like person size',
#  'nope meanwhil talk say make greet',
#  'im class get text',
#  'sm servic inclus text credit pl goto wwwcomuknet login qxj unsubscrib stop extra charg help comuk cm ae',
#  'ask dad pick lar wan stay meh',
#  'tht god gift bird human hav natur gift frm god',
#  'pleas leav topicsorri tell',
#  'collect ur laptop',
#  'well there lot thing happen lindsay new year sigh bar ptbo blue heron someth go',
#  'hmv bonu special pound genuin hmv voucher answer easi question play send hmv infowwwpercentrealcom',
#  'smile pleasur smile pain smile troubl pour like rain smile sum hurt u smile becoz someon still love see u smile',
#  'fuck cedar key fuck come anyway tho',
#  'probabl come everybodi done around ltgt right',
#  'nutter cutter ctter cttergg cttargg ctargg ctagg ie',
#  'aight see bit',
#  'e admin build might b slightli earlier ill call u im reach',
#  'wont anyth de',
#  'hai dear friend new amp present number rajitha raj ranju',
#  'object bf come',
#  'great send account number',
#  'gud niswt drmstake care',
#  'free tone hope enjoy new content text stop unsubscrib helpp provid tonesyoucouk',
#  'good dont need receiptswel done ye pleas tell what number could ring',
#  'ye place town meet excit adult singl uk txt chat pmsg',
#  'anyth valuabl situat first get second loos',
#  'mani peopl seem special first sight remain special till last sight maintain till life end shja',
#  'thank look realli appreci',
#  'still otsid leu come morrow maga',
#  'sent ltgt buck',
#  'aight latest probabl closer jay tyler two trip',
#  'sorri miss call let talk time im',
#  'ok lor earli still project meet',
#  'ok ill send ltdecimalgt ok',
#  'wont b tri sort hous ok',
#  'still around look pick later',
#  'pleas dont text anymor noth els say',
#  'leav yet ok lor go elsewher n eat u thk',
#  'reach home safe n sound liao',
#  'u subscrib best mobil content servic uk per day send stop helplin',
#  'arent next ltgt hour imma flip shit',
#  'day say cut ur hair paragon call hair sens noe much hair cut',
#  'id say that good sign well know track record read women',
#  'ugh dont wan na get bed warm',
#  'lay man let know miss thought great day send bimbo ugo number ill appreci safe',
#  'th juli',
#  'certainli put thing perspect someth like happen',
#  'xma reward wait comput randomli pick loyal mobil custom receiv reward call',
#  'im realli sorri lit hair fire',
#  'bloodi hell cant believ forgot surnam mr ill give u clue spanish begin',
#  'yeah give call youv got minut',
#  'r u say order slipper co pay return',
#  'want show world princess europ',
#  'say ltgt year old man money im last ltgt still wait check',
#  'found enc ltgt',
#  'two fundament cool life walk',
#  'im go lunch wif famili aft dat go str orchard lor',
#  'problem talk later',
#  'get offici england poli rington colour flag yer mobil tonight game text tone flag optout txt eng stop box wwx',
#  'themob check newest select content game tone gossip babe sport keep mobil fit funki text wap',
#  'ju an lar ull noe later',
#  'fact leav think addi goe back school tue wed',
#  'unfortun ive found pick sister airport even dont think ill go tri go one th',
#  'lol oh got friend dog',
#  'ball move lotwil spin last difficult bat',
#  'dont worri day big lambu ji vl cometil enjoy batchlor parti',
#  'also ive sorta blown coupl time recent id rather text blue look weed',
#  'send someon els',
#  'give us back id proof ltgt rs wont allow work come home within day',
#  'actual im wait week start put ad',
#  'ive tri reach without success',
#  'hi dahow today class',
#  'friend want drive em someplac probabl take',
#  'oh ho first time u use type word',
#  'sir receiv account anoth hr time sorri delay',
#  'sorri ill call later meet thing relat trade pleas call arul ltgt',
#  'blank blank wat blank lol',
#  'hmm bit piec lol sigh',
#  'well meant oppos drunken night',
#  'aiyar hard type u later free tell call n scold n tell u',
#  'pick variou point',
#  'good morn plz call sir',
#  'im diet ate mani slice pizza yesterday ugh im alway diet',
#  'remind download content alreadi paid goto httpdoit mymobi tv collect content',
#  'ye watch footi worri go blow phil nevil',
#  'part dont initi dont understand',
#  'captain room',
#  'plan pongal',
#  'haha leg neck kill amigo hope end night burn think could swing like hour',
#  'howz person stori',
#  'know hook mean right',
#  'suppos meet discuss abt trip thought xuhui told afternoon thought go lesson',
#  'gentl princess make sweet gentl love',
#  'hello need posh bird chap user trial prod champney put need address dob asap ta r',
#  'parti place usf charg contribut way greatli appreci yeah got room one',
#  'privat account statement',
#  'celebr bday els',
#  'u got person stori',
#  'si catch e show e afternoon im watch w c u wan watch today tmr lor',
#  'pl send compani name saibaba colani',
#  'ok everi night take warm bath drink cup milk youll see work magic still need loos weight know',
#  'kkit goodwhen go',
#  'man carlo definit come mu tonight excus',
#  'mum went dentist',
#  'u dont rememb old commerci',
#  'goodo ye must speak friday eggpotato ratio tortilla need',
#  'ne thing interest good birthday u wrking nxt start uni today',
#  'haha yeah see sec',
#  'hey what u sleep morn',
#  'dear got bu directli calicut',
#  'die e toot fring',
#  'ok',
#  'kkani special today',
#  'way home long dri spell season would',
#  'dai ltgt naal eruku',
#  'mm ye dear look hug p',
#  'ju finish blow hair u finish dinner alreadi',
#  'oh way food fridg want go meal tonight',
#  'still area restaur ill tri come back soon',
#  'eh den sat u book e kb liao huh',
#  'new theori argument win situat lose person dont argu ur friend kick amp say im alway correct',
#  'huh earli dinner outsid izzit',
#  'collect ur laptop go configur da set izzit',
#  'heard u call night knicker make beg like u last time xx luv nikiyunet',
#  'ou guarante latest nokia phone gb ipod mp player prize txt word collect ibhltd ldnwh pmtmsgrcvd',
#  'hi birth lb oz mother babi brilliantli',
#  'well slightli disastr class pm fav darl hope day ok coffe wld good cant stay late tomorrow time place alway',
#  'say thank',
#  'u make fb list',
#  'urgent mobil number award ukp prize guarante call landlin claim valid hr ppm',
#  'yup im elabor safeti aspect issu',
#  'carlo pick ill swing usf littl bit',
#  'miss',
#  'sexi sexi cum text im wet warm readi porn u fun msg free recd msg p inc vat cancel text stop',
#  'cash prize claim call',
#  'im meet call later',
#  'respons one power weapon occupi place other heart',
#  'dont think turn like randomlli within min open',
#  'camera award sipix digit camera call fromm landlin deliveri within day',
#  'get garden readi summer free select summer bulb seed worth scotsman saturday stop go notxtcouk',
#  'import custom servic announc premier call freephon',
#  'yo dude guess got arrest day',
#  'u free sat rite u wan watch infern affair wif n darren n mayb xy',
#  'kgive back thank',
#  'ummmmmaah mani mani happi return day dear sweet heart happi birthday dear',
#  'think mentor percent sure',
#  'wont believ true incred txt repli g learn truli amaz thing blow mind ofwd ptxt',
#  'ok lor im town lei',
#  'well give co said didnt one nighter persev found one cheap apologis advanc somewher sleep isnt',
#  'hospit da return home even',
#  'wat would u like ur birthday',
#  'haf u eaten wat time u wan come',
#  'tri contact repli offer video handset anytim network min unlimit text camcord repli call',
#  'knowyetund hasnt sent money yet sent text bother send dont involv anyth shouldnt impos anyth first place apologis',
#  'well imma definit need restock thanksgiv ill let know im',
#  'sound good finger make difficult type',
#  'hi msg meim offic',
#  'mani lick take get center tootsi pop',
#  'ive sent send',
#  'even friend priest call',
#  'yesh realli greatbhaji told kalli best cricket sachin worldveri tough get',
#  'mom want know',
#  'ew one',
#  'go sao mu today done',
#  'todaysundaysunday holidayso work',
#  'urgent tri contact u today draw show prize guarante call land line claim validhr',
#  'messagesom text miss sendernam miss number miss sentdat miss miss u lot that everyth miss sent via fullonsmscom',
#  'tri contact repli offer video phone anytim network min half price line rental camcord repli call',
#  'urgent nd attempt contact uu call b tcsbcmwcnxxcallcostppmmobilesvari max',
#  'spoke uncl john today strongli feel need sacrific keep he go call beg listen dont make promis make clear thing easi need pleas let us work thing long keep expect help creativ stifl pl keep happi promis part',
#  'shop eh ger toke abt syd lehhaha',
#  'pick receipt someth earlier',
#  'free call pa',
#  'wet right',
#  'happi babi alright take job hope fine send kiss make smile across sea kiss kiss',
#  'reason weve spoken year anyway great week best exam',
#  'happen r waxsto wat want come ill get medic insur shell abl deliv basic care im current shop right medic insur give til friday morn that ill see major person guid right insur',
#  'cool like swim pool jacuzzi hous',
#  'watch cartoon listen music amp eve go templ amp church u',
#  'urgh coach hot smell chip fat thank especi duvet predict text word',
#  'didnt get anyth da',
#  'oh ye like tortur watch england',
#  'thought didnt see',
#  'night sweet sleep well ive see exorc emili rose may never sleep hug snog',
#  'yo guess drop',
#  'babe feel let get itboth tri cheer upnot fit soo muchxxlov u locaxx',
#  'xam hall boy ask girl tell start term di answer den manag lot hesit n lookin around silent said intha ponnungal ipaditan',
#  'aiyo co sm neva repli wait repli lar tot havent finish ur lab wat',
#  'tri contact repli offer video handset anytim network min unlimit text camcord repli call',
#  'might accid tookplac somewher ghodbandar rd traffic move slove plz slip amp dont worri',
#  'urgent mobil xxx bonu caller prize nd attempt reach call asap boxnqp ppm',
#  'noe la u wana pei bf oso rite k lor day den',
#  'nice new shirt thing wear nudist theme mu',
#  'ur face test ltgt select number tell ur face astrolog wait quick repli',
#  'say hell give call friend got money he definit buy end week',
#  'ltgt ish minut minut ago wtf',
#  'win year suppli cd store ur choic worth enter weekli draw txt music tsc wwwldewcomsubswinppmx',
#  'oooh got plenti',
#  'erm woodland avenu somewher get parish magazin telephon number',
#  'today voda number end select receiv award hava match pleas call quot claim code standard rate app',
#  'frnd juz wordnot mere relationshipit silent promis say wherevr whenevr forevr gudnyt dear',
#  'affidavit say ltgt e twigg st divis g courtroom ltgt lttimegt ill doubl check text tomorrow',
#  'god ask forgiv littl child gave love repli',
#  'good even roger',
#  'playin space poker u',
#  'phone',
#  'great',
#  'usualiam fine happi amp well',
#  'dare chang ring',
#  'hope enjoy new content text stop unsubscrib helpp provid tonesyoucouk',
#  'today vodafon number end select receiv award number match call receiv award',
#  'dude got haircut breezi',
#  'knock knock txt whose enter r weekli draw gift voucher store yr choic tc wwwtklscom age stoptxtstopweek',
#  'also know lunch menu da know',
#  'want kfc tuesday buy meal gravi mark',
#  'oh great ill disturb talk',
#  'friendship game play word say doesnt start march end may tomorrow yesterday today e',
#  'orh tot u say still dun believ',
#  'tell quit long co havent finish film yet',
#  'thk got ta go home urself co ill b go shop fren present',
#  'thank honey still havent heard anyth leav bit longer crowd tri later great advic thank hope cardiff still',
#  'what ur pin',
#  'cool text your readi',
#  'readi call',
#  'day ask anand number',
#  'coffe cake guess',
#  'noth much chillin home super bowl plan',
#  'bore housew chat n date btnation rate pmin landlin',
#  'pussi perfect',
#  'btw regard realli tri see anyon els th guy commit random dude',
#  'shall call dear food',
#  'thought king hill thing',
#  'havent left yet probabl gon na til dinner',
#  'ever green quot ever told jerri cartoon person irrit u alway one love u vri much fail express gud nyt',
#  'new voicemail pleas call',
#  'urgent mobil number award prize guarante call land line claim valid hr ppm',
#  'joy father john john name joy father mandan',
#  'cheer u tex mecaus u werebor yeah okden hunni r uin wk satsound likeyour havin grfun j keep updat countinlot lovem xxxxx',
#  'famili respond anyth room went home diwali one call come make feel like die',
#  'think actual talk call boss morn went place last year told could go get car fix cheaper kept tell today much hope would come back alway regret get number etc',
#  'k k sm chat',
#  'reach ur home ltgt minut',
#  'know girl alway safe selfish know got pa thank good night',
#  'what come hill monster hope great day thing r go fine busi though',
#  'love one law make happi person love way friendship one law never make ur friend feel alon aliv gud night',
#  'ok leav need ask',
#  'av new number wil u use oneta',
#  'im workin get job',
#  'night end anoth day morn come special way may smile like sunni ray leav worri blue blue bay gud mrng',
#  'sfirst timedhoni rock',
#  'break time one come n get stuff fr',
#  'hope alright babe worri might felt bit despar learn job fake wait come back love',
#  'realli good see day dudett miss',
#  'haf enuff space got like mb',
#  'sorri ill call later',
#  'ok',
#  'weekend fine excus much decor',
#  'hey repli pa',
#  'late said websit didnt dont slipper',
#  'guarante award mayb even cash claim ur award call free legitimat efreefon number wat u think',
#  'sorri miss babe late slept hope enjoy drive lesson boytoy miss teas kiss',
#  'happen dear silent tens',
#  'mth half price orang line rental latest camera phone free phone mth call mobilesdirect free updat orstoptxt tc',
#  'u come back dinner rite dad ask confirm wif u',
#  'oh ki think wi nz player unsold',
#  'oooh bed ridden ey think',
#  'shall get pouch',
#  'how champ leav glasgow',
#  'none that happen til get though',
#  'yo call get chanc friend mine want ask big order',
#  'lmao take pic send',
#  'take away money worri',
#  'youd like wouldnt jerk',
#  'finish lunch alreadi u wake alreadi',
#  'guess ithi first time creat web page wwwasjesuscom read wrote im wait opinion want friend',
#  'come u got noth',
#  'pleas protect ethreat sib never ask sensit inform like passwordsatmsm pin thru email never share password anybodi',
#  'said problem let know',
#  'littl med say take everi hour pain back took anoth hope dont die',
#  'okcom home vl nice meet v chat',
#  'ye ammaelif take lot turn sit tri hold steer',
#  'probabl im almost ga get cash tomorrow',
#  'nan sonathaya soladha boss',
#  'erm thought contract ran theth octob',
#  'luv u soo much u dont understand special u r ring u morrow luv u xxx',
#  'kkhow sister kid',
#  'lastest stereophon marley dizze racal libertin stroke win nookii game flirt click themob wap bookmark text wap',
#  'number sir',
#  'get ticket walsal tue th march mate get sat ill pay treat want go txt bak terri',
#  'ceri u rebel sweet dreamz littl buddi c ya moro need bloke',
#  'argh fuck nobodi town',
#  'r mani modelsoni ericson also der ltgt luk good bt forgot modl',
#  'let know need anyth els salad desert someth mani beer shall get',
#  'thought id get watch co that kind thing u getanth love much',
#  'u better go sleep dun disturb u liao u wake msg lor',
#  'hospit da return home even',
#  'wan earli lei outsid wun b home earli neva mind',
#  'wat dear sleep ah',
#  'alreadysabarish ask go',
#  'like talk pa abl dont know',
#  'ju finish lunch way home lor tot u dun wan stay sch today',
#  'kick new season wk free goal news ur mobil txt ur club name eg villa',
#  'im use hope agent dont drop sinc ive book thing year whole boston nyc experi',
#  'oh god im gon na googl nearbi cliff',
#  'sorri cant take call right happen r waxsto wat want come ill get medic insur shell abl deliv basic care im current shop right medic insur give til friday morn that ill see major person guid right insur',
#  'dear voucher holder claim week offer pc pleas go httpwwwetlpcoukexpressoff tsc appli stop text txt stop',
#  'wat da decis',
#  'freerington repli real poli eg real pushbutton dontcha babygoodby golddigg webeburnin st tone free u join wk',
#  'friend use call',
#  'miss ya need ya want ya love ya',
#  'right wasnt phone someon number like',
#  'good morn princess happi new year',
#  'im town ill ju take mrt later',
#  'pl stop bootydeli f invit friend repli ye see wwwsmsacubootydeli stop send stop frnd',
#  'would ip address test consid comput isnt minecraft server',
#  'babe love cover face kiss',
#  'good afternoon boytoy feel today better hope good boy obedi slave pleas queen',
#  'stitch trouser',
#  'know call',
#  'im home pleas call',
#  'hey tmr meet bugi',
#  'ye rent expens way save',
#  'good morn dear shijutta great amp success day',
#  'cutest girl world',
#  'nope im drivin neva develop da photo lei',
#  'congratul ore mo owo wa enjoy wish mani happi moment fro wherev go',
#  'free msgwe bill mobil number mistak shortcod pleas call charg refundedthi call free bt landlin',
#  'im smoke peopl use wyli smoke much justifi ruin shit',
#  'kkim also finewhen complet cours',
#  'ur chang da report big co ive alreadi made chang da previou report',
#  'tell friend plan valentin day lturlgt',
#  'long sinc scream princess',
#  'still check da',
#  'friendship poem dear dear u r near hear dont get fear live cheer tear u r alway dear gud ni',
#  'want snow freez windi',
#  'take small dose tablet fever',
#  'wonder would okay call uncl john let know thing nigeria r ltgt dollar year sent know strain plan pay back everi dime give everi dime expect anyth practic someth like',
#  'housemaid murder coz man murder ltgt th januari public holiday govtinstituit closedinclud post officeunderstand',
#  'yeah like goe like friend imma flip shit like half hour',
#  'dear voucher holder claim week offer pc pleas go httpwwwwtlpcouktext tsc appli',
#  'spoil bed well',
#  'cab availablethey pick drop door step',
#  'ok sure time tho sure get librari class tri see point good eve',
#  'much pay suganya',
#  'im gon na rip uteru',
#  'movi laptop',
#  'piggi r u awak bet ure still sleep im go lunch',
#  'alway say welp',
#  'thank love torch bold',
#  'ok',
#  'forgot tell smth like number section clearer',
#  'there someon year ltgt toyota camri like mr olayiwola mileag ltgt kit clean need know much sell rais dough soon land sell holla back',
#  'hey happi birthday',
#  'uhhhhrmm isnt tb test bad your sick',
#  'love set soul fire spark flame big rawr flame xoxo',
#  'get ten billion call text help god',
#  'n funni',
#  ...]

# %%
y_train
# Out:
# 191     0
# 1423    0
# 3030    0
# 3772    0
# 3209    0
#        ..
# 3776    1
# 1206    1
# 443     0
# 4519    0
# 4505    0
# Name: v1, Length: 3900, dtype: int64

# %%
y_test
# Out:
# 2639    0
# 2724    0
# 1668    0
# 828     0
# 5293    0
#        ..
# 5203    0
# 2273    0
# 4308    0
# 1661    0
# 1448    1
# Name: v1, Length: 1672, dtype: int64

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer()

x_train_tfidf = tfidf.fit_transform(x_train)
x_test_tfidf = tfidf.transform(x_test)

# %%
x_train_tfidf
# Out:
# <3900x5783 sparse matrix of type '<class 'numpy.float64'>'
# 	with 31754 stored elements in Compressed Sparse Row format>

# %%
x_test_tfidf
# Out:
# <1672x5783 sparse matrix of type '<class 'numpy.float64'>'
# 	with 12013 stored elements in Compressed Sparse Row format>

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB

rfc = RandomForestClassifier(random_state=1)
lr = LogisticRegression()
nb = MultinomialNB()

model1 = rfc.fit(x_train_tfidf,y_train)
model2 = lr.fit(x_train_tfidf,y_train)
model3 = nb.fit(x_train_tfidf,y_train)

# %%
y_pred1 = model1.predict(x_test_tfidf)
y_pred2 = model2.predict(x_test_tfidf)
y_pred3 = model3.predict(x_test_tfidf)

# %%
from sklearn.metrics import accuracy_score, mean_squared_error,mean_absolute_error, classification_report
print(accuracy_score(y_pred1,y_test))
print(accuracy_score(y_pred2,y_test))
print(accuracy_score(y_pred3,y_test))
# Out:
# 0.9778708133971292
# 0.9712918660287081
# 0.9742822966507177

# %%
print(mean_squared_error(y_pred1,y_test))
print(mean_squared_error(y_pred2,y_test))
print(mean_squared_error(y_pred3,y_test))
# Out:
# 0.022129186602870814
# 0.028708133971291867
# 0.025717703349282296

# %%
print(mean_absolute_error(y_pred1,y_test))
print(mean_absolute_error(y_pred2,y_test))
print(mean_absolute_error(y_pred3,y_test))
# Out:
# 0.022129186602870814
# 0.028708133971291867
# 0.025717703349282296

# %%
print("Classification Report for RandomForestClassifier:")
print(classification_report(y_test, y_pred1))

print("Classification Report for Logistic Regression:")
print(classification_report(y_test, y_pred2))

print("Classification Report for Naice Bayes:")
print(classification_report(y_test, y_pred3))
# Out:
# Classification Report for RandomForestClassifier:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1479
#            1       0.99      0.81      0.89       193
#
#     accuracy                           0.98      1672
#    macro avg       0.98      0.91      0.94      1672
# weighted avg       0.98      0.98      0.98      1672
#
# Classification Report for Logistic Regression:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      1479
#            1       0.98      0.77      0.86       193
#
#     accuracy                           0.97      1672
#    macro avg       0.98      0.88      0.92      1672
# weighted avg       0.97      0.97      0.97      1672
#
# Classification Report for Naice Bayes:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      1479
#            1       0.99      0.78      0.88       193
#
#     accuracy                           0.97      1672
#    macro avg       0.98      0.89      0.93      1672
# weighted avg       0.97      0.97      0.97      1672
